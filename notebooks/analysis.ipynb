# %%
import pandas as pd
import os.path
from pathlib import Path
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

pd.set_option('display.expand_frame_repr', False)

out_path = '/net/isilonP/public/rw/homes/uni_adm/tmp/log_parsing/2021.01.06-19.33.40/'
reduce_path = os.path.join(out_path, 'reduce')
results_path = os.path.join(out_path, 'results')

Path(results_path).mkdir(exist_ok=True)

# %% [markdown]
# # Overview
#
# The data presented here is from parsing the log file from 2018-01-01 to 2020-07-16. There are several filtering steps:
#
# 1. User agent is checked to make sure it doesn't look like a bot/crawler:
#     * For all requests (API & Browser):
#         * comparing against a regex eg `(bot|crawler...)`
#         * Removing any uknown `-`
#     * For only browser requests:
#         * for non-api requests by using [ua-parser](https://github.com/ua-parser) to ensure the browser name is valid
#         * Filter on the main browsers (eg Chrome, Firefox, IE, ...)
# 2. Must be a `GET` request
# 3. Request must be a success (`200`)

# %%
df_bytes = pd.read_csv(os.path.join(reduce_path, 'bytes.csv'), names=[
    'date',
    'bytes',
])
df_bytes = df_bytes.groupby('date').sum().sort_index()
### First log day
print(df_bytes.index.min())
### Last log day
print(df_bytes.index.max())
# Out:
# 2018-01-01
# 2020-07-16

# %% [markdown]
# # Queries by user type and namespace

# %%
# use nrows=1e6 to limit for testing
df = pd.read_csv(os.path.join(reduce_path, 'parsed.csv'), names=[
    'namespace',
    'user-type',
    'user-agent-family',
    'query'
])

# %%
user_agent_family_whitelist = {
    'Chrome',
    'Firefox'
    'IE',
    'Opera',
    'Safari',
    'Edge',
    'Netscape',
    'Mobile Safari',
    'Sogou Explorer',
    'Chrome Mobile',
    'UC Browser',
    'Chromium',
    'Samsung Internet',
    'Chrome Mobile iOS',
    'Vivaldi',
    'Yandex Browser',
    'Chrome Mobile WebView',
    'Apple Mail',
    'Android',
    'Mobile Safari UI/WKWebView',
    'Firefox Mobile',
    'Opera Mobile'
}

# %%
def save_csv_for_all_namespaces(dfin):
    namespaces = set(dfin['namespace'])
    user_types = set(dfin['user-type'])
    assert len(user_types) == 1
    user_type = list(user_types)[0]
    for namespace in namespaces:
        csv_path = os.path.join(results_path, f'{user_type}_{namespace}.csv')
        partitioned = dfin[(dfin['user-type']==user_type) & (dfin['namespace']==namespace)]['query'].value_counts()
        if not partitioned.empty:
            reordered = partitioned.reset_index().rename(columns={'index':'query','query':'count'})[['count', 'query']]
            print(f'User type={user_type} Namespace={namespace}')
            print(reordered.head(25).to_string(index=False))
            print('-'*75, '\n'*2)
            reordered.to_csv(csv_path, index=False)

# %% [markdown]
# ### Browser breakdown

# %%
df_browser = df[(df['user-agent-family'].isin(user_agent_family_whitelist) & (df['user-type'] == 'browser'))]
df_browser['user-agent-family'].value_counts()
# Out:
# Chrome                        21860892
# Safari                         3049246
# Edge                           2864460
# Chrome Mobile                  2167489
# Opera                          1369151
# Mobile Safari                   491886
# Sogou Explorer                  458777
# Netscape                        351653
# UC Browser                      304696
# Chrome Mobile WebView           234224
# Chromium                         63194
# Yandex Browser                   31887
# Chrome Mobile iOS                27903
# Samsung Internet                 24025
# Firefox Mobile                   17938
# Vivaldi                          16848
# Mobile Safari UI/WKWebView       15813
# Android                           9047
# Apple Mail                        8447
# Opera Mobile                      4057
# Name: user-agent-family, dtype: int64

# %% [markdown]
# ### Top 25 browser queries for each namespace

# %%
save_csv_for_all_namespaces(df_browser)
# Out:
# User type=browser Namespace=locations
#  count                  query
#    221               membrane
#    215                      *
#    206                nucleus
#    194          cell membrane
#    175     name:cell membrane
#    142   name:golgi apparatus
#    135               secreted
#    123        plasma membrane
#    120           mitochondria
#     92              cytoplasm
#     89          mitochondrion
#     82               lysosome
#     78                 id:162
#     73          extracellular
#     54  endoplasmic reticulum
#     41              nucleolus
#     41          transmembrane
#     41            chloroplast
#     41               endosome
#     37                  golgi
#     36             peroxisome
#     35                cytosol
#     31                      ,
#     30                nuclear
#     28           cell surface
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=uniref
#  count                                         query
#   5004                                             *
#   2068                                       3 and â
#    808                                             â
#    617                                          î±1a
#    615                                    neuronatin
#    510                                       insulin
#    457                                        q9bzs1
#    327              uniprot:q06828* and identity:1.0
#    231              uniprot:q06828* and identity:0.5
#    230                                        ãâ±1a
#    225                         hemoglobin beta chain
#    221  uniprot:(transcription factors) identity:0.5
#    218                                  identity:0.5
#    213                                         human
#    208                      uniprot:(*) identity:1.0
#    208           uniprot:(reviewed:yes) identity:0.5
#    200                                        p01990
#    199           uniprot:(reviewed:yes) identity:0.9
#    194                                        p68871
#    193                                  identity:0.9
#    189                                  homo sapiens
#    188                  uniprot:(*) and identity:0.9
#    185                                  identity:1.0
#    182           uniprot:(reviewed:yes) identity:1.0
#    179                              ddi2_mouse and â
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=uniprot
#   count                                              query
#  194885                                    replaces:p08107
#  188891                                                  *
#  173670                         organism:9606 and q96l92-4
#  173130                         organism:9606 and a4qph2-3
#  173053                           organism:9606 and q96f92
#  172987                           organism:9606 and p0c5w0
#  172724                           organism:9606 and q96l16
#  143892                                       reviewed:yes
#   88520  organism:9606 and reviewed uniprotunreviewed u...
#   86663                           organism:9606 and q9h761
#   84272                           organism:9606 and q3zb72
#   81971                           organism:9606 and p63154
#   81821                           organism:9606 and q6zst8
#   76272                           organism:9606 and q99mq1
#   45092                           organism:9606 and q07424
#   44925                           organism:9606 and q9jkq4
#   44848                           organism:9606 and q91v10
#   44615                                            insulin
#   44522                         organism:9606 and o70273-3
#   42665                           organism:9606 and o08792
#   42389                           organism:9606 and q5u4e2
#   42224                           organism:9606 and q9erl0
#   42108                         organism:9606 and q9wvg6-2
#   41552                           organism:9606 and q5jua8
#   41249                       organism:9606 and a0a0a6yvq5
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=keywords
#  count                     query
#   2798            phosphoprotein
#   2502                    signal
#   1687      alternative splicing
#   1561              glycoprotein
#   1402                  secreted
#   1379               acetylation
#   1216                  membrane
#    870                  immunity
#    846              polymorphism
#    791            disulfide bond
#    779             mitochondrion
#    741                cell cycle
#    646                   nucleus
#    628  transcription regulation
#    618           ubl conjugation
#    501          disease mutation
#    482            oxidoreductase
#    464             transmembrane
#    448                 cytoplasm
#    446       transmembrane helix
#    443        nucleotide-binding
#    433                 transport
#    432           innate immunity
#    404               atp-binding
#    400               coiled coil
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=taxonomy
#  count                             query
#  11014                  solyc05g018060.1
#   5562                                 *
#   1678                      homo sapiens
#   1604                             human
#   1074                     ancestor:9606
#    618                             mouse
#    572                  escherichia coli
#    522  host:homo sapiens (human) [9606]
#    466                      mus musculus
#    450          saccharomyces cerevisiae
#    419                               rat
#    416                     ancestor:2759
#    375                        ancestor:2
#    368                     lactobacillus
#    333                   ancestor:131567
#    319              arabidopsis thaliana
#    315                          bacteria
#    299                      complete:yes
#    290                          bacillus
#    290            pseudomonas aeruginosa
#    276             staphylococcus aureus
#    272                 bacillus subtilis
#    269                               hba
#    269                              homo
#    267                       clostridium
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=uniparc
#  count                                              query
#   1207                               proteome:up000017358
#    914                                       proteome:(*)
#    432                                                  *
#    396                                        cluster:(*)
#    259                                                  â
#    235                                             q9bzs1
#    216                                            insulin
#    206                               proteome:up000001509
#    185                                              igf1r
#    155                                              human
#    147                                         hemoglobin
#    119                                            3 and â
#    113                                                p53
#    111                                       homo sapiens
#     98                                           â  and i
#     90  papain family cysteine protease [arabidopsis t...
#     88                                            keratin
#     86                                        np_001619.1
#     84                                            vitamin
#     80                                       wp_033111888
#     78                               proteome:up000029103
#     78                               proteome:up000006737
#     77                                     uniprot:p35869
#     77                                            ensembl
#     75                                            albumin
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=database
#  count                            query
#   3667                                *
#    138                              p53
#    132                          insulin
#     92                             egfr
#     90                            human
#     72                             ace2
#     70                       hemoglobin
#     59                            brca1
#     57                         mn908947
#     56                             tp53
#     52                        2019-ncov
#     51                          albumin
#     51                             h7n9
#     47                          protein
#     45                         covid-19
#     45                         collagen
#     42                             sars
#     41                          keratin
#     40                       sars-cov-2
#     38                              gfp
#     38                            actin
#     37  category:3d structure databases
#     35                          amylase
#     34                     homo sapiens
#     33                      coronavirus
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=mapping
#  count                                              query
#      4                                        ipi00212593
#      4  yourlist:m201904108471c63d39733769f8e060b50655...
#      4                                        ipi00022418
#      3  yourlist:m202003058471c63d39733769f8e060b50655...
#      3                                                 cs
#      3  yourlist:m20200306e5a08bb0b2d1c45b0c7bc3b55fd2...
#      3  yourlist:m20191001216da2b77bfbd2e6699ca9b6d1c4...
#      3  yourlist:m201906178471c63d39733769f8e060b50655...
#      3                                          225441373
#      3  yourlist:m20200716e5a08bb0b2d1c45b0c7bc3b55fd2...
#      2  yourlist:m20191111216da2b77bfbd2e6699ca9b6d1c4...
#      2                                          659086226
#      2                                          355359291
#      2                                           15617138
#      2                                        ipi00000816
#      2  yourlist:m201906145c475328cef75220c360d524e9d4...
#      2  yourlist:m202007018471c63d39733769f8e060b50655...
#      2  yourlist:m202005218bc4d7ade02784b0c2481c7f3de0...
#      2  yourlist:m201906145c475328cef75220c360d524e9d4...
#      2  yourlist:m201909255c475328cef75220c360d524e9d4...
#      2  yourlist:m20191001e5a08bb0b2d1c45b0c7bc3b55fd2...
#      2  yourlist:m202006188471c63d39733769f8e060b50655...
#      2                                        ipi00119063
#      2                                        ipi00783987
#      2                                         1239946261
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=diseases
#  count                            query
#    423                    name:disorder
#    295                    breast cancer
#    252                    name:syndrome
#    239                                *
#    212                        alzheimer
#    198                         diabetes
#    195                           cancer
#    189                         leukemia
#    141                  prostate cancer
#     92                        parkinson
#     84                      lung cancer
#     80                             braf
#     73                  cystic fibrosis
#     56                alexander disease
#     53                             sma2
#     48                diabetes mellitus
#     41               sickle cell anemia
#     39                parkinson disease
#     35                       alzheimers
#     35                         covid-19
#     34                         epilepsy
#     34  amyotrophic lateral sclerosis 1
#     33                              hiv
#     32                              sex
#     32             rheumatoid arthritis
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=citations
#  count                                             query
#   4332                                                 *
#    346                              author:oppermann f s
#    338                                 author:graves g r
#    165                                  author:ashburner
#    164                                    published:1951
#    159                              author:pierson l s 3
#    150                                   author:sanger f
#    144  kuopio ischaemic heart disease risk factor study
#     76                                     finckh parkin
#     76                      citedin:(p93003) and 9330910
#     75            mappedin:(uniprot:p01256) and 12030813
#     46                         title:protein interaction
#     35                                               *--
#     34                                           insulin
#     33                                journal:j exp biol
#     32                                           author:
#     30                          author:sottrup-jensen l.
#     29                                  author:phelps k.
#     28                                           osmotin
#     28                                                10
#     27                                       citedin:(*)
#     25                               author:hillier l.w.
#     25                                 turnip peroxidase
#     23                                         clusterin
#     23                                   author:senba t.
# ---------------------------------------------------------------------------
#
#
# User type=browser Namespace=proteomes
#  count                     query
#  19023                         *
#   6913              homo sapiens
#   6418                     human
#   2537             taxonomy:9606
#   1985              redundant:no
#   1700                      homo
#   1691                     mouse
#   1657          escherichia coli
#   1614              mus musculus
#    987     staphylococcus aureus
#    903  saccharomyces cerevisiae
#    811                     yeast
#    708                    e coli
#    627                       rat
#    602                bos taurus
#    601             reference:yes
#    549            taxonomy:10090
#    539                      9606
#    521               arabidopsis
#    521   drosophila melanogaster
#    503      arabidopsis thaliana
#    470            id:up000005640
#    467                    bovine
#    432               homo sapien
#    420                drosophila
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Programmatic library breakdown

# %%
df_programmatic = df[df['user-type'] == 'programmatic']
df_programmatic['user-agent-family'].value_counts()
# Out:
# Python Requests      91524425
# Python-urllib        28091465
# Other                 9090621
# libwww-perl           7194876
# curl                  1837109
# Apache-HttpClient       36606
# WordPress                   3
# Android                     3
# Name: user-agent-family, dtype: int64

# %% [markdown]
# ### Top 25 programmatic queries for each namespace

# %%
save_csv_for_all_namespaces(df_programmatic)
# Out:
# User type=programmatic Namespace=locations
#  count             query
#     42       name:values
#     41     name:analytes
#     39       name:ranges
#     39    name:indicates
#     38     name:extracts
#     38  name:metabolites
#     36     name:cannabis
#     35      name:samples
#     33    name:compounds
#     31     name:suggests
#     30  name:cannabinoid
#     29       name:limits
#     28     name:requires
#     26         name:acid
#     25        name:study
#     25  name:cannabidiol
#     24       name:method
#     24   name:bioaerosol
#     24       name:sativa
#     23         name:mean
#     23        name:delta
#     22      name:methods
#     22        name:novel
#     22          name:rat
#     22    name:marijuana
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=uniref
#  count                                              query
#    500  uniprot:(lactococcus lactococcus lactis) and i...
#    204  uniprot:(faecalibaculum faecalibaculum rodenti...
#    185                                      member:q03063
#    163  uniprot:(romboutsia romboutsia sp. dr1) and id...
#    143  uniprot:(oscillibacter oscillibacter sp. 1-3) ...
#    107  uniprot:(clostridium uncultured clostridium sp...
#     99  uniprot:(bacteroides bacteroides sp. cag:927) ...
#     97  uniprot:(oscillibacter oscillibacter sp. er4) ...
#     87                                             p02931
#     83                                             p0afg0
#     83                                             p0a6x3
#     82                                             p08515
#     82                                             p53184
#     82             uniprot:(lactococcus) and identity:1.0
#     82                                             p00743
#     82                                             b4sl31
#     82                                             p0a8n5
#     81                                             s0akj8
#     81                                             p0aex9
#     80                                             p0aff6
#     80                                             a8gbz7
#     80                                             p63165
#     80                                             p23908
#     80                                             p0agd1
#     80                                             p85173
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=uniprot
#    count                                query
#  2189992                       wp_010890415.1
#   137613                      gene_exact:zw10
#   112105                           albu_human
#    87754                           igkc_human
#    84209                           flna_human
#    66485  reviewed:yes organism:9606 gene:nan
#    48129                           fibb_human
#    41667                           finc_human
#    39626                          ighg1_human
#    38934                 accession:a0a1j5kg84
#    38431                           fibg_human
#    35811                 accession:a0a1v0lbh4
#    30816                           vime_human
#    30798                           tagl_human
#    26766                            id:p00533
#    26465         mnemonic:p00533 or id:p00533
#    26343                 accession:a0a1j9tqd1
#    24972                              peptide
#    24877       organism:9606 and reviewed:yes
#    23481       reviewed:yes and organism:9606
#    23402                 accession:a0a1i5hri1
#    22938                           ahnk_human
#    22863                           ighm_human
#    22074                 accession:a0a1c4c0c3
#    22029                           fiba_human
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=keywords
#  count             query
#    514                 *
#     45     name:analytes
#     43       name:values
#     41    name:indicates
#     39       name:ranges
#     39      name:samples
#     39     name:extracts
#     37     name:cannabis
#     37  name:metabolites
#     33    name:compounds
#     32     name:suggests
#     30  name:cannabinoid
#     30       name:limits
#     28     name:requires
#     25        name:study
#     25  name:cannabidiol
#     25         name:acid
#     24         name:mean
#     24   name:bioaerosol
#     24       name:method
#     23       name:sativa
#     22        name:novel
#     22      name:methods
#     22    name:marijuana
#     22        name:delta
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=taxonomy
#  count                                              query
#   4414                     triticum turgidum subsp. durum
#   4145                                           zea mays
#   2518               aegilops tauschii subsp. strangulata
#   2034                             <built-in function id>
#   1717                                                gca
#   1550                                                gcf
#   1489                                  triticum aestivum
#   1466                                         sus scrofa
#   1443                            drosophila melanogaster
#   1396                                drosophila simulans
#   1394                                      daphnia magna
#   1253                            aureobasidium pullulans
#   1136                     hordeum vulgare subsp. vulgare
#   1063                            rhizophagus irregularis
#    913                           drosophila pseudoobscura
#    886                                       glycine soja
#    827                           bos indicus x bos taurus
#    822                                macrostomum lignano
#    784                       oryza sativa subsp. japonica
#    770                                       homo sapiens
#    758  rhizophagus irregularis (strain daom 181602 / ...
#    755                                               bact
#    737                                 aquilegia coerulea
#    721                                  nicotiana tabacum
#    703                                     vitis vinifera
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=uniparc
#  count                                              query
#   6824  checksum:d3767ab49010536b or checksum:3df02727...
#   6060                                      no data found
#   5315  checksum:1370bf3e72bb84b3 or checksum:8fcc902d...
#   4446  checksum:e2723416d5e4b880 or checksum:a34f0ff1...
#   4216  checksum:3a0d391deffa5275 or checksum:bf260c51...
#   3464  checksum:7f5d099ff1455d7b or checksum:4db3656f...
#   3220  checksum:e350dbcab8d5aa9d or checksum:bd9c81a4...
#   3176  checksum:a2f10f664bb01080 or checksum:791024ac...
#   3102  checksum:ffae3f9b6e379d6c or checksum:d1b3e74a...
#   3080  checksum:5c6a20207f69ce2d or checksum:094b02b4...
#   2871  checksum:313cadc0d5b3842a or checksum:300fba0c...
#   2661  checksum:69902e52270db2df or checksum:f17103e8...
#   2635  checksum:01d7b932a20a5cef or checksum:4403ff51...
#   2630  checksum:5f96aa3ca1743f74 or checksum:5533f28f...
#   2497  checksum:98e42e725272c7d1 or checksum:ee117818...
#   2383  checksum:9d955844dac47619 or checksum:354939b2...
#   2316  checksum:a2d7ecb944e29332 or checksum:d4b100a9...
#   2226  checksum:ec744aed416be1c2 or checksum:71c8e0dc...
#   2206  checksum:4fde361bd76cc485 or checksum:d96a6802...
#   2186                                           aml99881
#   1983  checksum:dfd352ed63e0cd06 or checksum:69902e52...
#   1973  checksum:5d6134ca95fb1698 or checksum:a4d88dc5...
#   1848  checksum:3c79ec5169f6fbec or checksum:d3e82616...
#   1820  checksum:d3767ab49010536b or checksum:3df02727...
#   1818  checksum:fb239526a49bd4ad or checksum:ab798e4a...
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=database
#  count             query
#     40       name:values
#     38     name:analytes
#     38  name:metabolites
#     37     name:cannabis
#     36     name:extracts
#     34    name:indicates
#     34       name:ranges
#     33    name:compounds
#     32      name:samples
#     31     name:suggests
#     30  name:cannabinoid
#     28     name:requires
#     26         name:acid
#     26       name:limits
#     25  name:cannabidiol
#     25        name:study
#     24       name:method
#     24       name:sativa
#     24   name:bioaerosol
#     24         name:mean
#     23        name:delta
#     22        name:novel
#     22      name:methods
#     22          name:rat
#     21         name:high
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=mapping
#  count                                              query
#     10                       515374,538202,5881724,114591
#      1                                             b5zc00
#      1                                             a2z669
#      1                                            nummern
#      1                                                tau
#      1                                          id:q02910
#      1                                  p20840_sag1_yeast
#      1  yourlist:m20190617e5a08bb0b2d1c45b0c7bc3b55fd2...
#      1                                  p07204_trbm_human
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=diseases
#  count             query
#     47     name:analytes
#     45  name:metabolites
#     44       name:values
#     42    name:indicates
#     42    name:compounds
#     41     name:extracts
#     41      name:samples
#     41       name:ranges
#     40     name:cannabis
#     38     name:suggests
#     37       name:limits
#     31     name:requires
#     28  name:cannabinoid
#     27        name:means
#     26   name:bioaerosol
#     26         name:acid
#     25  name:cannabidiol
#     25       name:sativa
#     25       name:method
#     25        name:study
#     25     name:presents
#     24         name:mean
#     24          name:rat
#     24        name:doses
#     24     name:agonists
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=citations
#  count             query
#     46     name:analytes
#     43       name:values
#     41    name:indicates
#     40       name:ranges
#     40     name:extracts
#     40      name:samples
#     38  name:metabolites
#     36     name:cannabis
#     35       name:limits
#     33    name:compounds
#     32     name:suggests
#     31              rpob
#     30  name:cannabinoid
#     28     name:requires
#     26         name:acid
#     25        name:study
#     25   name:bioaerosol
#     24  name:cannabidiol
#     24        name:means
#     24       name:sativa
#     23        name:delta
#     23        name:doses
#     23         name:mean
#     23       name:method
#     22      name:methods
# ---------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=proteomes
#  count                                         query
#   1623                                           dsm
#   1621                                          atcc
#    595                                    salmonella
#    592                                 streptococcus
#    592                                 lactobacillus
#    590                                         human
#    589                                           cat
#    588                                         mouse
#    377                              saccharomycotina
#    373                              taphrinomycotina
#    364                                pezizomycotina
#    315                                 basidiomycota
#    286                                fungi -dikarya
#    206        taxonomy:acinetobacter baumannii [470]
#    202                                             *
#    127                   taxonomy:2759 reference:yes
#    105  callorhinchus and milii not taxonomy:viruses
#     86                                          asfv
#     85                                  homo_sapiens
#     64                         neisseria gonorrhoeae
#     56                                   taxonomy:24
#     56                                 taxonomy:4577
#     52                                  redundant:no
#     49                      taxonomy:24 redundant:no
#     47                                 name:analytes
# ---------------------------------------------------------------------------
