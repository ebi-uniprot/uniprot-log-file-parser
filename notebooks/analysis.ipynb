# %%
import pandas as pd
import os.path
from pathlib import Path
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth',100)

out_path = '/net/isilonP/public/rw/homes/uni_adm/tmp/log_parsing/2021.01.08-16.58.35'
reduce_path = os.path.join(out_path, 'reduce')
results_path = os.path.join(out_path, 'results')

Path(results_path).mkdir(exist_ok=True)

# %% [markdown]
# # Overview
#
# The data presented here is from parsing the log file from 2018-01-01 to 2020-07-16. There are several filtering steps:
#
# 1. Bots/crawlers are removed by looking at each request's user agent string using [ua-parser](https://github.com/ua-parser)
# 2. Removing any uknown user agent strings eg `-`
# 3. Must be a `GET` request
# 4. Request must be a success (`200`)
# 5. Must not be a faceted query ie includes `&fil=` in the resource.

# %%
df_bytes = pd.read_csv(os.path.join(reduce_path, 'bytes.csv'), names=[
    'date',
    'bytes',
])
df_bytes = df_bytes.groupby('date').sum().sort_index()

# %%
df_bytes.index.min()
# Out:
# '2018-01-01'

# %%
df_bytes.index.max()
# Out:
# '2020-07-16'

# %% [markdown]
# # Queries by user type and namespace

# %%
# use nrows=1e6 to limit for testing
df = pd.read_csv(os.path.join(reduce_path, 'parsed.csv'), encoding='utf-8', names=[
    'Namespace',
    'Application',
    'Query'
])

# %%
def save_csv_for_all_namespaces(dfin, user_type):
    namespaces = set(dfin['Namespace'])
    for namespace in namespaces:
        csv_path = os.path.join(results_path, f'{user_type}_{namespace}.csv')
        partitioned = dfin[dfin['Namespace']==namespace]['Query'].value_counts()
        if not partitioned.empty:
            reordered = partitioned.reset_index().rename(columns={'index':'Query','Query':'Count'})[['Count', 'Query']]
            print(f'User type={user_type} Namespace={namespace}')
            print(reordered.head(100).to_string(index=False))
            print('-'*100, '\n'*2)
            reordered.to_csv(csv_path, index=False, encoding='utf-8')

# %% [markdown]
# ### Application breakdown

# %%
df_counts = df['Application'].value_counts().to_frame()
df_counts['Percentage'] = df_counts['Application'] / sum(df_counts['Application'])
df_counts.style.format({
    'Percentage': '{:,.2%}'.format,
})
# Out:
# <style  type="text/css" >
# </style><table id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Application</th>        <th class="col_heading level0 col1" >Percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row0" class="row_heading level0 row0" >Python Requests</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row0_col0" class="data row0 col0" >99861490</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row0_col1" class="data row0 col1" >52.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row1" class="row_heading level0 row1" >Chrome</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row1_col0" class="data row1 col0" >21587862</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row1_col1" class="data row1 col1" >11.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row2" class="row_heading level0 row2" >Apache-HttpClient</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row2_col0" class="data row2 col0" >17345401</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row2_col1" class="data row2 col1" >9.15%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row3" class="row_heading level0 row3" >Wget</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row3_col0" class="data row3 col0" >10590939</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row3_col1" class="data row3 col1" >5.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row4" class="row_heading level0 row4" >Firefox</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row4_col0" class="data row4 col0" >8431076</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row4_col1" class="data row4 col1" >4.45%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row5" class="row_heading level0 row5" >libwww-perl</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row5_col0" class="data row5 col0" >7771644</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row5_col1" class="data row5 col1" >4.10%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row6" class="row_heading level0 row6" >IE</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row6_col0" class="data row6 col0" >4758045</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row6_col1" class="data row6 col1" >2.51%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row7" class="row_heading level0 row7" >Bytespider</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row7_col0" class="data row7 col0" >3257142</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row7_col1" class="data row7 col1" >1.72%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row8" class="row_heading level0 row8" >Safari</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row8_col0" class="data row8 col0" >3049134</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row8_col1" class="data row8 col1" >1.61%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row9" class="row_heading level0 row9" >Edge</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row9_col0" class="data row9 col0" >2854941</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row9_col1" class="data row9 col1" >1.51%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row10" class="row_heading level0 row10" >curl</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row10_col0" class="data row10 col0" >2513980</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row10_col1" class="data row10 col1" >1.33%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row11" class="row_heading level0 row11" >Chrome Mobile</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row11_col0" class="data row11 col0" >2501043</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row11_col1" class="data row11 col1" >1.32%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row12" class="row_heading level0 row12" >Opera</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row12_col0" class="data row12 col0" >1527728</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row12_col1" class="data row12 col1" >0.81%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row13" class="row_heading level0 row13" >QQ Browser</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row13_col0" class="data row13 col0" >733137</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row13_col1" class="data row13 col1" >0.39%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row14" class="row_heading level0 row14" >Mobile Safari</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row14_col0" class="data row14 col0" >533761</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row14_col1" class="data row14 col1" >0.28%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row15" class="row_heading level0 row15" >Sogou Explorer</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row15_col0" class="data row15 col0" >434915</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row15_col1" class="data row15 col1" >0.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row16" class="row_heading level0 row16" >Maxthon</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row16_col0" class="data row16 col0" >433510</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row16_col1" class="data row16 col1" >0.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row17" class="row_heading level0 row17" >Netscape</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row17_col0" class="data row17 col0" >404733</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row17_col1" class="data row17 col1" >0.21%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06level0_row18" class="row_heading level0 row18" >UC Browser</th>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row18_col0" class="data row18 col0" >288967</td>
#                         <td id="T_72c8e11e_51f4_11eb_bb99_37fc7c087e06row18_col1" class="data row18 col1" >0.15%</td>
#             </tr>
#             <tr>
#                         <th id="T_72c8e11e_5

# %% [markdown]
# Out of curiosity had a look at the Thunderbird and Facebook queries:

# %%
set(df[df['Application'] == 'Thunderbird']['Query'])
# Out:
# {'interpro ipr014000 or interpro ipr014002 or interpro ipr014003', 'tegument'}

# %%
set(df[df['Application'] == 'Facebook']['Query'])
# Out:
# {'*',
#  '1.-.-.- taxonomy:acromyrmex echinatior (panamanian leafcutter ant) (acromyrmex octospinosus echinatior) [103372]',
#  '10-kda',
#  '1093da',
#  '1avw',
#  '1ema',
#  '1oel',
#  '1p 34.2 duplication',
#  '1p34.2 duplication',
#  '1q21',
#  '2.4.1.19',
#  '3 hydroxyanthranilate 3 4 dioxygenase',
#  '3.2.1.41',
#  '3faw',
#  '3faw pullulanase',
#  '6.4.1.1.',
#  '94 aa',
#  'aa 500',
#  'aa 500 features',
#  'aah10943',
#  'ab010145',
#  'abdominal aortic aneurysm',
#  'acad9',
#  'accession:p04637',
#  'accession:p38398',
#  'accession:p84243',
#  'accession:q9nzc9',
#  'actin',
#  'adn',
#  'adrenocorticotropic',
#  'af013254',
#  'af043303',
#  'af052018 or af052017 or af052016 or af052015 or af052014 or af019908 or af134518 or af134517 or af134516 or af134515 or af134514 or af133430',
#  'af304460',
#  'akt',
#  'alanina',
#  'alanine',
#  'albumin',
#  'albumin rat',
#  'albúmina',
#  'alcohol dehydrogenase',
#  'ali',
#  'alk5',
#  'amylase',
#  'ancestor:1643685',
#  'ancestor:4896',
#  'ancestor:7208',
#  'ancestor:8711',
#  'ancestor:9844',
#  'annotation:(type:ca_bind) database:(type:pdb)',
#  'anti pd1',
#  'anti pd1  for hamster',
#  'anti pd1 hamster',
#  'anti streptococcus suis',
#  'apolipoprotein a-i',
#  'app',
#  'aqp7',
#  'arf6',
#  'aspidelaps',
#  'atheris squamigera',
#  'author:adler d.h.',
#  'author:de muinck keizer s.m.p.f.',
#  'author:gregory s.g.',
#  'author:hasegawa y.',
#  'author:helip-wooley a.',
#  'author:herrmann r.g.',
#  'author:jahnsen t.',
#  'author:pickard r.t.',
#  'author:shapiro l.h.',
#  'author:sharp j.d.',
#  'author:shattuck d.',
#  'author:skalhegg b.s.',
#  'author:thiyagarajan n.',
#  'author:tollervey d.',
#  'author:woolford c.a.',
#  'autophagy-related protein 13',
#  'ay358023 or ay358022',
#  'ay632535',
#  'bachi',
#  'bachi in rhodobacter',
#  'baci rhodobacter capsulatus',
#  'baeg',
#  'bchi',
#  'bchi (rhodobacter capsulatus )',
#  'bchi rhodobacter capsulatus',
#  'bchirhodobacter capsultes',
#  'bchl',
#  'bchl(rhodobactercapsultes)',
#  'bcl',
#  'bdnf',
#  'bee',
#  'biomphalaria',
#  'biomphalaria and acad9',
#  'blacked',
#  'botulinum toxin',
#  'bovine casein sequence',
#  'bpl porin tabol',
#  'brassica oleracea var. capitata',
#  'brca1 gene',
#  'burkholderia pseudomallei',
#  'burkholderia pseudomallei trehalose-6-phosphate synthase',
#  'cancer',
#  'cas11',
#  'caseine',
#  'caspase',
#  'caspaze',
#  'ccu',
#  'cd16 antibody',
#  'cecropin',
#  'cftr saimiri sciureus',
#  'chick',
#  'cholera',
#  'chymosin',
#  'clostridium',
#  'clp',
#  'cluster:(uniprot:a0kfe5* identity:1.0) not id:a0kfe5',
#  'cluster:(uniprot:f6q468* identity:1.0) not id:f6q468',
#  'cluster:(uniprot:p39050* identity:0.9) not id:p39050',
#  'cluster:(uniprot:p59594* identity:1.0) not id:p59594',
#  'cluster:(uniprot:p59637* identity:1.0) not id:p59637',
#  'cluster:(uniprot:q6ewl8* identity:1.0) not id:q6ewl8',
#  'cluster:(uniprot:q9byf1* identity:0.9) not id:q9byf1',
#  'cluster:(uniprot:q9uhj6* identity:0.9) not id:q9uhj6',
#  'collagen',
#  'collision',
#  'cov-19',
#  'covid',
#  'covid 19',
#  'covid-19',
#  'covid19',
#  'cristae',
#  'cunt',
#  'cxxc',
#  'database:(type:embl af043303)',
#  'database:(type:embl ay274119)',
#  'database:(type:embl dq217792)',
#  'database:(type:embl dq838640) or database:(type:embl dq838635) or database:(type:embl dq838645) or database:(type:embl dq841262) or database:(type:embl dq838599) or database:(type:embl dq838650) or database:(type:embl dq838615) or database:(type:embl dq838620) or database:(type:embl dq838625) or database:(type:embl dq838630) or database:(type:embl dq838610)',
#  'database:(type:embl eu707943)',
#  'database:(type:embl j01917)',
#  'database:(type:embl k03455)',
#  'database:(type:embl m87661)',
#  'database:(type:mim 608232)',
#  'diabetes',
#  'disease:()',
#  'disease:46,xx sex reversal 1 [di-02395]',
#  'drosha',
#  'dutpase e coli',
#  'e coli periplasm',
#  'ec:1.-.-.- reviewed:yes',
#  'ec:1.1.1.- reviewed:yes',
#  'ec:2.7.1.- reviewed:yes',
#  'ec:4.2.2.2 database:(type:pdb)',
#  'ec:5.3.3.- reviewed:yes',
#  'ec:5.3.3.3 reviewed:yes',
#  'efcibp',
#  'egfr',
#  'egfr exon 20',
#  'elastina',
#  'enpep',
#  'enzyme tyrosinase',
#  'escherichia coli',
#  'f-box only protein 11',
#  'family:aromatic acid exporter arae (tc 2.a.85) family',
#  'family:autoinducer synthase family',
#  'family:bacterial flagellin family',
#  'family:betacoronaviruses spike protein family',
#  'family:phospholipase a2 family',
#  'family:protein kinase superfamily. agc ser/thr protein kinase family. s6 kinase subfamily',
#  'family:snake three-finger toxin family',
#  'family:upf0149 family',
#  'family:yeet/ykfh/ypjj family',
#  'fbn1',
#  'fbxo11',
#  'fella',
#  'ferritin',
#  'fgf1',
#  'fibronectin',
#  'flor bcr cfla family efflux transporter',
#  'foxl2',
#  'fr693807',
#  'fr693807.2',
#  'fructose 2,6-bisphospatase',
#  'fructose 2,6-bisphospatate',
#  'fructozo-2,6-bisfosforan',
#  'frx',
#  'fut2',
#  'g-protein coupled receptor',
#  'gaa68849',
#  'gedunin',
#  'gen hla-b',
#  'gene',
#  'gene ier3',
#  'gene med15',
#  'gene sling',
#  'gene:hsp26',
#  'gene:mfsd2 and taxonomy:primates',
#  'gene_exact:p2ry12',
#  'geranyl diphosphate synthase',
#  'girasa',
#  'glucagon',
#  'glucose oxidase',
#  'glukolin',
#  'glutelin',
#  'gluteline',
#  'glutelins',
#  'glycine max',
#  'guy',
#  'gène',
#  'h10n8 neuraminidase',
#  'hemoglobin',
#  'hemoglobin alfa',
#  'hemoglobin alpha',
#  'hevbr',
#  'hexa',
#  'histamina key',
#  'histamine',
#  'histamineh key',
#  'histatin',
#  'histatin 9',
#  'histitina8',
#  'histon h2',
#  'hisyamine',
#  'homeblastalignretrieve/id mappingpeptide searchsparqlcontacthelp taxonomy - middle east respiratory syndrome-related coronavirus',
#  'host:homo sapiens (human) [9606]',
#  'hras',
#  'huntington',
#  'hydrolize tcpc',
#  'hydrolyzes tcpc',
#  'hymenochate luteobadia',
#  'id:2429 or id:2430',
#  'id:a0a0e2pg44 or id:a0a1g7gfz0',
#  'id:p26378',
#  'id:p60757 or id:q9s762 or id:q8gsj1 or id:p00499 or id:a0a286u2j1 or id:q8x8t4 or id:q7n6i0 or id:q49776 or id:c6df77 or id:q8zfx4',
#  'il-2 rat',
#  'import alpha',
#  'integrin alpha',
#  'interleukin 1 receptor antagonist',
#  'islet cells',
#  'j99',
#  'jak',
#  'jnk',
#  'job:m2018011483c3dd8ce55183c76102dc5d3a26728b00467df',
#  'job:m201801148a530b6ca0138afaa6d2b97ce8c2a9240046528',
#  'job:m201811098a530b6ca0138afaa6d2b97ce8c2a92401fc2dy',
#  'job:m20190401216da2b77bfbd2e6699ca9b6d1c41eb20d698fa',
#  'job:p20181209e6ab09cada7e802395c04de1af96da0e2fda54o',
#  'job:p201910215c475328cef75220c360d524e9d456ce00c4a01',
#  'job:p202003128bc4d7ade02784b0c2481c7f3de0963a003859n',
#  'kcna',
#  'keratin',
#  'kluai namwa',
#  'kras',
#  'l-norvaline',
#  'la séquance de protéine p00698',
#  'lactic',
#  'lama glama',
#  'lbd39',
#  'leishmania donovani',
#  'leishmenia donovani',
#  'lencina',
#  'leucina',
#  'lipasas',
#  'listeria virus 100 gp58',
#  'locations:(location:membrane) taxonomy:bacteria and reviewed:yes',
#  'locations:(location:peripheral membrane protein [sl-9903]) and reviewed:yes',
#  'lpo',
#  'lxenopus',
#  'lysozyme hen egg',
#  'm12i',
#  'm16248',
#  'macrophage metalloelastase',
#  'mao a',
#  'mappedsequence:j3qr84-1 or mappedsequence:q96fv2-1 or sequence:j3qr84',
#  'mappedsequence:p68871-1 or mappedsequence:a0a0j9ywk4-1 or sequence:p68871',
#  'mappedsequence:q9hc84-1 or mappedsequence:h0ydx8-1 or sequence:q9hc84',
#  'mdmx',
#  'mecp2',
#  'menthone',
#  'mers',
#  'mers spike site',
#  'methanol 2020',
#  'methanol production',
#  'methanol production 2020',
#  'mfs transporter acinetobacter baumanii',
#  'mic60',
#  'microginin',
#  'mioglobin',
#  'mitochondrial pyruvate carrier',
#  'mnn9',
#  'mouse',
#  'mouse genes',
#  'mpas',
#  'mrna',
#  'mthfr',
#  'mthft',
#  'mucin',
#  'mucins mg1',
#  'mx2',
#  'mx2 equine influenza',
#  'mx2 equine virus',
#  'mx2 horse',
#  'myb',
#  'myba1',
#  'myh7',
#  'myoglobin',
#  'myosin sus scrofa domesticus',
#  'myosine',
#  'name:disorder',
#  'name:disorderfbxo11',
#  'name:hpt  organism:bacillus subtilis ',
#  'name:lipoprotein signal peptidase taxonomy:proteobacteria (9prot) [1224]',
#  'name:syndrome',
#  'name:tyrosine kinase organism:mouse length:[600 to 1000]',
#  'nelfa',
#  'nik',
#  'nm_001291897',
#  'nmda r',
#  'nod2',
#  'np-001315986',
#  'nras',
#  'nuclease organism:helicobacter pylori',
#  'orf1a',
#  'orf1ab',
#  'orf7a',
#  'organism:1314 pathway:484.341',
#  'organism:266834 strain:41',
#  'organism:405948 pathway:295.240',
#  'organism:9606 pathway:460.143',
#  'organism:escherichia coli mass:[30000 to 32000]',
#  'organism:escherichia phage t5',
#  'organism:plasmodium falciparum',
#  'oryctolagus cuniculus musculus',
#  'ovalbumin',
#  'ovulation',
#  'oxch_human',
#  'p0275',
#  'p16',
#  'p39',
#  'p53',
#  'pan troglodytes',
#  'pan troglodytes egfr exon 20',
#  'pan troglodytes exon 20',
#  'pancreatic lipase',
#  'pd_1',
#  'pdgf',
#  'pepck-c',
#  'pepsin',
#  'peptidyl transferase',
#  'period gene',
#  'peroxidase taxonomy:mammalia [40674] not name:inhibitor not name:activator not name:probable reviewed:yes gene',
#  'pfemp1',
#  'pgsv3',
#  'phosphodiesterase',
#  'phyllomedusa bicolor',
#  'pkr',
#  'plant',
#  'plantaricin',
#  'plasmodium falciparum',
#  'plasmodium falciparum eryhtrocyte',
#  'plasmodium falciparum eryhtrocyte membrane protein',
#  'plasmodium falciparum erythocyte',
#  'pmm2',
#  'porcodio',
#  'potassium transporters in neurons',
#  'ppap',
#  'pppvepeptp',
#  'presynaptic nmda r',
#  'primary structure of insulin',
#  'protein p39',
#  'protein parvovirus',
#  'proteome:up000000840 and proteomecomponent:genome',
#  'proteome:up000002277 (proteomecomponent:chromosome 7)',
#  'proteome:up000002438',
#  'proteome:up000005640 and proteomecomponent:chromosome 1',
#  'proteome:up000005640 and proteomecomponent:chromosome 7',
#  'proteome:up000005640 and proteomecomponent:unplaced',
#  'proteome:up000006735',
#  'proteome:up000028501 and proteomecomponent:chromosome',
#  'proteome:up000144472',
#  'proteome:up000144472 and proteomecomponent:genome',
#  'proteome:up000246478',
#  'proteome:up000464024',
#  'proteome:up000464024 reviewed:yes',
#  'pth',
#  'purn',
#  'purn hub',
#  'q8nfj6',
#  'rdrp sars-covs',
#  'restriction endonuclease subunit s',
#  'restriction enzyme',
#  'reviewed:no',
#  'reviewed:no taxonomy:7742',
#  'reviewed:no taxonomy:89902',
#  'reviewed:yes',
#  'reviewed:yes existence:evidence at protein level [1] fragment:no',
#  'reviewed:yes human cytochrome',
#  'reviewed:yes not database:(type:pdb)',
#  'reviewed:yes taxonomy:$1 gene:egf',
#  'rice dep1',
#  'rs1800206',
#  'saccharomyces cerevisiae',
#  'sads-cov',
#  'sars',
#  'sars corona virus enzyme',
#  'sars-cov-2',
#  'sars2 spike glycoprotein',
#  'sarscov',
#  'sarscov2',
#  'schizophrenia and organism:homo sapiens (human) [9606]',
#  'school',
#  'semen clusterin',
#  'serrs',
#  'sine oculis',
#  'sirt 1',
#  'sox9',
#  'spaz',
#  'sr proteins',
#  'src   –   plcg   -   shc1   -   grb2   -  pik3r1',
#  'staphylococcus epidermis lipase',
#  'streotococcus pyogenes speb',
#  'streptococcus bovis',
#  'tak1',
#  'taxonomy:40674',
#  'taxonomy:4952 hmga',
#  'taxonomy:canis lupus familiaris (dog) (canis familiaris) [9615] 0000139 goa:(metal ion binding [46872]) go:0000139',
#  'taxonomy:mycobacterium tuberculosis complex [77643] membrane',
#  'taxonomy:mycobacterium tuberculosis complex [77643] porin',
#  'tbk1',
#  'tbpa p. multocida',
#  'thermomyces langinosus',
#  'thrombin',
#  'trehalose-phosphatase',
#  'tt1751',
#  'tubulin',
#  'tyrosinase',
#  'u88536',
#  'ubiquitin',
#  'ubiquiton ligase rnf170',
#  'ubiqutin',
#  'uniprot:(leu asp gly arg arg arg arg gly arg gly glu asn stop arg asn thr and organism:homo sapiens (human) [9606]) identity:1.0',
#  'var2csa',
#  'vegt',
#  'vicilin',
#  'x03700',
#  'x04370',
#  'x04615 and taxonomy:viruses',
#  'x71946',
#  'xenopus',
#  'yourlist:m20180112a7434721e10ee6586998a056ccd0537e2586aa9',
#  'yourlist:m20180114f725f458ac8690f874dd868e4ed79b88e3eaeai',
#  'yourlist:m20180414aafb7e4d2f1d05654627429e83da5ccefb72c56',
#  'yourlist:m20180713aafb7e4d2f1d05654627429e83da5cce057fe7f',
#  'yourlist:m2018081783c3dd8ce55183c76102dc5d3a26728b23e64dy',
#  'yourlist:m20180826a7434721e10ee6586998a056ccd0537ea443d2k',
#  'yourlist:m2018100983c3dd8ce55183c76102dc5d3a26728b2c8004u',
#  'yourlist:m20181028f725f458ac8690f874dd868e4ed79b88014a357',
#  'yourlist:m201903068471c63d39733769f8e060b506551e120835620',
#  'yourlist:m20190306e5a08bb0b2d1c45b0c7bc3b55fd265560248081',
#  'yourlist:m20190411216da2b77bfbd2e6699ca9b6d1c41eb200a905m',
#  'yourlist:m20190414216da2b77bfbd2e6699ca9b6d1c41eb201945d1',
#  'yourlist:m20190421216da2b77bfbd2e6699ca9b6d1c41eb205ee5ee',
#  'yourlist:m2020032763e7e78cfc6242b71761763234ff46dc0b60e35',
#  'yourlist:m2020032763e7e78cfc6242b71761763234ff46dc0b6155c',
#  'yourlist:m20200327a2a5a37cd3ff71f97605b695f360a9fa0b5a30l',
#  'yourlist:m20200614216da2b77bfbd2e6699ca9b6d1c41eb29070ecw',
#  'yrp7',
#  'zebrafish',
#  'α-synuclein'}

# %% [markdown]
# ### Partition the queries
# Restrict queries submitted by these applications to as they constitute the vast majority and will help filter any bots user agents that are actually bots:

# %%
programmatic_apps = {
    'Python Requests',
    'Wget',
    'Apache-HttpClient',
    'libwww-perl',
    'curl',
    'Java'
}
browser_apps = {
    'Chrome',
    'IE',
    'Firefox',
    'Opera',
    'Safari',
    'QQ Browser',
    'Edge',
    'Netscape',
    'Mobile Safari',
    'Sogou Explorer',
    'Chrome Mobile',
    'UC Browser',
    'Chromium',
    'Samsung Internet',
    'Chrome Mobile iOS',
}
assert not len(programmatic_apps & browser_apps)
df_browser = df[df['Application'].isin(browser_apps)]
df_programmatic = df[df['Application'].isin(programmatic_apps)]

# %% [markdown]
# Percentage of browser queries considered:

# %%
100*len(df_browser)/(len(df) - len(df_programmatic))
# Out:
# 91.59568102533402

# %% [markdown]
# Percentage of programmatic queries considered:

# %%
100*len(df_programmatic)/(len(df) - len(df_browser))
# Out:
# 96.95768795603531

# %% [markdown]
# ### Top 100 browser queries for each namespace

# %%
save_csv_for_all_namespaces(df_browser, 'browser')
# Out:
# User type=browser Namespace=citations
#  Count                                             Query
#   4939                                                 *
#    480                         title:protein interaction
#    434  kuopio ischaemic heart disease risk factor study
#    352                              author:oppermann f s
#    344                                 author:graves g r
#    312                                  author:ashburner
#    307                                    published:1951
#    264                              author:pierson l s 3
#    260                                   author:sanger f
#    138                             journal:j. exp. biol.
#    127                                  author:sanger f.
#    124                           author:pierson l.s. iii
#    113                      citedin:(p93003) and 9330910
#    112            mappedin:(uniprot:p01256) and 12030813
#    104                                     finckh parkin
#     80                                journal:j exp biol
#     57                             author:nicol d.s.h.w.
#     54                                       citedin:(*)
#     50                                           insulin
#     42                                               *--
#     41                             author:solal-cohen j.
#     37                                      mappedin:(*)
#     35                          author:sottrup-jensen l.
#     34                                           author:
#     33                                  author:phelps k.
#     31                               author:hillier l.w.
#     31                                                *�
#     29                                   author:senba t.
#     28                                                10
#     28                                           osmotin
#     27                 mappedin:(uniprot:(reviewed:yes))
#     27                                  author:kim k.-n.
#     26                                 author:vorgerd m.
#     26                               author:baldwin d.t.
#     26                                  author:kent w.j.
#     26                                 author:smith l.f.
#     25                               author:de vivo d.c.
#     25                                 turnip peroxidase
#     24                                    author:hide w.
#     24                                 author:edwards j.
#     24                                    author:baba m.
#     24                               author:ashburner m.
#     24                                     ph plant cell
#     23                                    author:ikeo k.
#     23                                          ?6102963
#     23                                   author:liu e.t.
#     23                                         clusterin
#     23                              author:naeslund a.k.
#     23                           author:merkle-lehman d.
#     23                               author:grafham d.v.
#     23                              author:canfield r.e.
#     23                                 author:akman h.o.
#     22                                         ?11680886
#     22                                 author:joberty g.
#     22                                            o75874
#     21                                      author:li j.
#     21                                              opa1
#     21                                      author:li h.
#     21                                         ?11079567
#     21                               author:quinzii c.m.
#     20                       author:ferreiro-barros c.c.
#     20                                    author:camp m.
#     20                                          ?9740056
#     20                                        luciferase
#     20                        id:29522901 or id:31194991
#     20                                     photosciology
#     20                                      author:wu j.
#     20                                      ctbp binding
#     20                                          ?8740180
#     19                                          ?9504818
#     19                                      author:du f.
#     19                                          ?6604220
#     19                                 author:sindern e.
#     18                                author:barros m.h.
#     18                                          ?9150929
#     18                                 author:dimauro s.
#     18                                     author:hao t.
#     18                                  author:hirano m.
#     18                                         ?11680894
#     17                                         ?12429849
#     17                                               p53
#     17                              author:hoya-arias r.
#     17                                            slc4a7
#     17                                   author:zhang g.
#     17                                     author:sun l.
#     17                                      author:li l.
#     17                                          caffeine
#     17                                    author:wang x.
#     17                           aids and journal:nature
#     17                                     author:liu x.
#     17                                      author:li y.
#     17                                         ?10036779
#     16                                             trap1
#     16                                      author:ye m.
#     16                                    author:zhou y.
#     16                                         ?15590099
#     16                                    author:chen q.
#     16                                    journal:nature
#     16                                         monkeypox
#     16                           author:sanna-cherchi s.
# ----------------------------------------------------------------------------------------------------
#
#
# User type=browser Namespace=locations
#  Count                                 Query
#   1168                    name:cell membrane
#    530                  name:golgi apparatus
#    338                              membrane
#    305                                     *
#    273                               nucleus
#    268                         cell membrane
#    178                          mitochondria
#    164                              secreted
#    156                       plasma membrane
#    131                             cytoplasm
#    129                         mitochondrion
#    108                              lysosome
#    106                                id:162
#     94                         extracellular
#     77                 endoplasmic reticulum
#     66                              endosome
#     57                         transmembrane
#     57                               nuclear
#     57                           chloroplast
#     56                            peroxisome
#     55                               cytosol
#     51                                 golgi
#     49                             nucleolus
#     48                          cytoskeleton
#     44                                     ,
#     39                       golgi apparatus
#     38                               exosome
#     37                               synapse
#     37                              ribosome
#     36                          cell surface
#     29                                plasma
#     28                             cell wall
#     28                               vacuole
#     28                                 human
#     26                                 actin
#     26                            centrosome
#     26                                    er
#     26                         mitochondrial
#     26                            chromosome
#     25                         late endosome
#     24                                   p53
#     24                  carica papaya l bhlh
#     24                                cilium
#     22                  extracellular matrix
#     22                               surface
#     22                         lipid droplet
#     22                               insulin
#     21                            cajal body
#     21                        outer membrane
#     20                               vesicle
#     20                            centromere
#     20                         autophagosome
#     20                       cell projection
#     20                     basement membrane
#     19                            perikaryon
#     19                         intracellular
#     19                                  ura3
#     19                      nuclear membrane
#     19                    recycling endosome
#     19                             flagellum
#     18                             centriole
#     18                  extracellular region
#     18                         lamellipodium
#     18                            sarcolemma
#     18                                 id:39
#     18                          name:nucleus
#     17                            melanosome
#     17                   extracellular space
#     17                                  mito
#     17                  apical cell membrane
#     17   single-pass type i membrane protein
#     17                        focal adhesion
#     17                       cleavage furrow
#     17                     secretory vesicle
#     17                              dendrite
#     16           peripheral membrane protein
#     16                              symplast
#     15                             myofibril
#     15                               midbody
#     15                         name:membrane
#     15                                p-body
#     15                        early endosome
#     15                             thylakoid
#     15                     adherens junction
#     15                        stress granule
#     14                       cilium membrane
#     14                        inner membrane
#     14                               plastid
#     14                           nucleoplasm
#     14                  mitochondrion matrix
#     14                             lysosomes
#     14  single-pass type ii membrane protein
#     14                              bacteria
#     13                         cell junction
#     13                             sarcomere
#     13                                ruffle
#     13                sarcoplasmic reticulum
#     13                           single pass
#     13                           synaptosome
#     13                             microsome
# ----------------------------------------------------------------------------------------------------
#
#
# User type=browser Namespace=uniparc
#  Count                                                                                                Query
#   2082                                                                                 proteome:up000017358
#   1607                                                                                         proteome:(*)
#    711                                                                                                    *
#    594                                                                                          cluster:(*)
#    270                                                                                               q9bzs1
#    266                                                                                 proteome:up000001509
#    254                                                                                                    â
#    251                                                                                              insulin
#    227                                                                                                human
#    185                                                                                                igf1r
#    182                                                                                           hemoglobin
#    147                                                                                         homo sapiens
#    145                                                                                                  p53
#    120                                                                                              keratin
#    118                                                                                              3 and â
#    112                                                                                 proteome:up000006737
#    110                                               papain family cysteine protease [arabidopsis thaliana]
#    107                                                                                     taxonomy:(virus)
#    106                                                                                     uniprot:(p07612)
#    106                                                                                              ensembl
#    103                                                                                 organism:(host:9606)
#    103                                                                                 proteome:up000029103
#    100                                                                                             â  and i
#     92                                                                                 proteome:up000000955
#     92                                                                                 proteome:up000007036
#     89                                                                                              albumin
#     88                                                                                         wp_033111888
#     87                                                             proteomecomponent:up000001509|chromosome
#     87                                                                                 proteome:up000033080
#     86                                                                                          np_001619.1
#     85                                                                                 proteome:up000001689
#     84                                                                                              vitamin
#     81                                                                                       uniprot:c3z8i0
#     81                                                                                               p62158
#     77                                                                                       uniprot:p35869
#     74                                                                                             pub74738
#     73                                                                                 proteome:up000000596
#     71                                                                                                brca1
#     70                                                                                               q48wd8
#     68                                                                                 proteome:up000001478
#     66                                                                                                igf19
#     64                                                                                               myosin
#     63                                                                                                  gfp
#     63                                                                                 proteome:up000008083
#     59                                                                                               p62988
#     59                                                                                                  app
#     58                                                                                               q3itx1
#     57                                                                                            myoglobin
#     57                                                                                                  syk
#     56                                                                                 proteome:up000028955
#     55                                                                                             bacteria
#     55                                                                                 proteome:up000007027
#     54                                                                                                 tp53
#     54                                                                                               p38398
#     54                                                                                               p40956
#     54                                                                                 proteome:up000027429
#     53                                                                                             collagen
#     53                                                                                                actin
#     53                                                                                               p08107
#     52                                                                                                    1
#     51                                                                                             lysozyme
#     51                                                                                 proteome:up000182246
#     50                                                                                 proteome:up000007729
#     49                                                             proteomecomponent:up000001689|chromosome
#     49                                                                                 bovine serum albumin
#     47                                                                                                    p
#     47                                                                                               p06239
#     47                                                             proteomecomponent:up000029103|chromosome
#     47                                                                                 anti-atherosclerosis
#     46                                                                                 proteome:up000030788
#     45                                                                                 proteome:up000018979
#     45                                                                                     escherichia coli
#     44                                                                                               p07612
#     44                                                                                             insuline
#     44                                                                                 proteome:up000011827
#     43                                                                                 proteome:up000028484
#     42                                                                                 proteome:up000012006
#     42                                               proteomecomponent:up000014613|unassembled wgs sequence
#     42                                                                                               p01308
#     41  id:upi0000000001 or id:upi0000000002 or id:upi0000000003 or id:upi0000000004 or id:upi0000000005...
#     41                                                                                                  hbb
#     41                                                                                             covid-19
#     41                                                                                     acid phosphatase
#     41                                                                                 proteome:up000003914
#     41                                                                                 proteome:up000027293
#     41                                                                                                  bsa
#     40                                                                                 proteome:up000063127
#     40                                                                                          coronavirus
#     40                                                                 proteome:(taxonomy:eukaryota [2759])
#     40                                                                                                 sars
#     40                                                                                               a8pz80
#     39                                                                                           a0a1d3rae2
#     39                                                                                                  hiv
#     39                                                                                 proteome:up000010085
#     38                                                                         created:[current to current]
#     38                                                                                               casein
#     37                                                                                          haemoglobin
#     37                                                                                                  epo
#     37                                                                            cluster:(uniref50_q54dm9)
#     37                                                                           src family tyrosine kinase
# ----------------------------------------------------------------------------------------------------
#
#
# User type=browser Namespace=database
#  Count                                           Query
#   4438                                               *
#   2127                     category:sequence databases
#   1309                 category:3d structure databases
#    972            category:family and domain databases
#    672            category:organism-specific databases
#    519  category:protein-protein interaction databases
#    316    category:polymorphism and mutation databases
#    264           category:enzyme and pathway databases
#    250              category:gene expression databases
#    248                 category:phylogenomic databases
#    226         category:protein family/group databases
#    180                    category:proteomic databases
#    179            category:genome annotation databases
#    166                                             p53
#    149                                         insulin
#    140                          category:ptm databases
#    131                                            egfr
#     91                                           human
#     83                                            ace2
#     83                                      hemoglobin
#     81                                           brca1
#     79                                            tp53
#     74                                         albumin
#     74                       category:2d gel databases
#     67                                       2019-ncov
#     64                                        mn908947
#     62                                            h7n9
#     60                                        covid-19
#     56                                            sars
#     55                                         keratin
#     54                              category:chemistry
#     51                                             gfp
#     51                                             pdb
#     50                                      sars-cov-2
#     49                                    homo sapiens
#     49                                        collagen
#     48                                     coronavirus
#     47                                           actin
#     45                                  category:other
#     45                                          p06968
#     44                                         genbank
#     43                                         protein
#     40                                            pfam
#     39                                            pd-1
#     39                                       myoglobin
#     38                                         amylase
#     38                                          e.coli
#     37                                            pten
#     36                                        bc060830
#     35                             category:ontologies
#     34      category:protocols and materials databases
#     34                                            cftr
#     34                                             pd1
#     34                                            kegg
#     33                                           gapdh
#     32                                             tau
#     31                                             tnf
#     31                                       nm_000230
#     31                                          x01714
#     30                                             *--
#     30                                        interpro
#     30                                        lysozyme
#     29                                              *�
#     29                                          casein
#     29                                           rad51
#     29                   tomato yellow leaf curl virus
#     29                                           id:70
#     28                                            ncbi
#     27                                            kras
#     27                                           pd-l1
#     27                                           brca2
#     27                                         trypsin
#     26                                   鸡传染性法氏囊病病毒vp3
#     25                                           id:28
#     25                                            her2
#     24                                           mouse
#     24                                             cd3
#     24                                            asfv
#     23                                         dutpase
#     23                                           covid
#     23                                           id:73
#     23                                            embl
#     23                                          refseq
#     23                                             shh
#     23                                    mus musculus
#     23                                             hbv
#     22                                             bax
#     22                                        catalase
#     22                                             hbb
#     22                                   human insulin
#     22                                     haemoglobin
#     22                                             sod
#     22                                            il-6
#     22                                         tubulin
#     22                                             bsa
#     22                                             app
#     22                                             myc
#     22                                            rice
#     21                                             afp
#     21                                            vegf
# ----------------------------------------------------------------------------------------------------
#
#
# User type=browser Namespace=uniref
#  Count                                                                                                Query
#   6434                                                                                                    *
#   2072                                                                                              3 and â
#    809                                                                                                    â
#    612                                                                                                 î±1a
#    554                                                                                              insulin
#    466                                                                                               q9bzs1
#    365                                                                                         identity:0.5
#    360                                                                             uniprot:(*) identity:1.0
#    345                                                         uniprot:(transcription factors) identity:0.5
#    333                                                                     uniprot:q06828* and identity:1.0
#    326                                                                         uniprot:(*) and identity:0.9
#    321                                                                                           neuronatin
#    314                                                                  uniprot:(reviewed:yes) identity:0.5
#    296                                                                                         identity:1.0
#    294                                                                                hemoglobin beta chain
#    282                                                                  uniprot:(reviewed:yes) identity:0.9
#    277                                                                             uniprot:(*) identity:0.9
#    277                                                                                         identity:0.9
#    274                                                                  uniprot:(reviewed:yes) identity:1.0
#    264                                                                             uniprot:(*) identity:0.5
#    255                                                                                                human
#    243                                                                    uniprot:(neuronatin) identity:0.9
#    233                                                                     uniprot:q06828* and identity:0.5
#    230                                                                                               ãâ±1a
#    203                                                                                         homo sapiens
#    189                                                                                              keratin
#    184  uniprot:(tumor length:[300 to 400] annotation:(type:disease) reviewed:yes organism:homo sapiens ...
#    179                                                                                     ddi2_mouse and â
#    179                                                                                                  *--
#    178  uniprot:(ec:3.1.26.- ribonuclease e) length:[500 to 2000] not fragment and identity:0.9 not ribo...
#    172                                                                                           hemoglobin
#    168                                                   uniprot:(bar headed goose hemoglobin) identity:0.9
#    166                                                                      uniprot:(protease) identity:1.0
#    163                                                                                               p68871
#    162                                                                     uniprot:q06828* and identity:0.9
#    161                                                                                               p01990
#    157                                                                                                  cd4
#    152                                                                     uniprot:q15019* and identity:0.5
#    150                                                                              0.ellipsis 0 ellipsis b
#    142                                                                                           ãâ  and i
#    141                                                                                                  p53
#    139                                                                         uniprot:(*) and identity:1.0
#    134                                                                                               p17275
#    133                                                                                            myoglobin
#    129                                                        uniprot:(author:steiner d f) and identity:1.0
#    125                                                                           moeo5 and uniref100_a0a011
#    124                                                                         uniprot:(*) and identity:0.5
#    124                                                   uniprot:(neuronatin and reviewed:yes) identity:0.9
#    118                                                          taxonomy:(complete:yes) id:uniref100_a0fgr8
#    117                                                                     uniprot:p02741* and identity:1.0
#    112                                                                        uniprot:(a0av96) identity:1.0
#    111                                                          uniprot:(transcription factor) identity:0.5
#    108  uniprot:(goa:(antibiotic transport [42891]) and organism:stenotrophomonas maltophilia (pseudomon...
#    105                                                             cluster:uniref50_a0a023gpj0 identity:0.9
#    104                                                             organism:(host:9606) id:uniref100_o12158
#    103                                                            uniparc:upi000006dbc1 id:uniref100_p11142
#    100                                                                                                brca1
#     98  uniprot:(tumor length:[300 to 400] annotation:(type:disease) and reviewed:yes and organism:homo ...
#     95                                                                                               p13569
#     95                                                                                           tyrosinase
#     93                                                                                                 ace2
#     92                                                           probable e3 ubiquitin-protein ligase herc5
#     90                                                                                              albumin
#     89                                                                  uniprot:(homo sapiens) identity:1.0
#     88                                                                                             uniref90
#     86                                                                                             bacteria
#     86                                                                                                brca2
#     86                                                                                     sulfotransferase
#     86                                                                                             collagen
#     85                                                                                        human insulin
#     85                                          uniprot:(organism:homo sapiens (human) [9606]) identity:1.0
#     84  uniprot:(family:group ii decarboxylase family and organism:homo sapiens (human) [9606]) identity...
#     82                                                                                              laccase
#     81                                                                                         mus musculus
#     81                                                            uniprot:(author:nishi m) and identity:0.9
#     80                                                                                                actin
#     79                         uniprot:(reviewed:yes and organism:homo sapiens (human) [9606]) identity:1.0
#     78                                                                                                 rpod
#     74                                                                     uniprot:q15019* and identity:0.9
#     73                                                                                               p05412
#     72                                                uniprot:(taxonomy:viridiplantae [33090]) identity:1.0
#     72                                                                                            human cyc
#     70                                                                                                 egfr
#     70  uniprot:(family:group ii decarboxylase family and organism:homo sapiens (human) [9606]) identity...
#     70                                                                                                   *�
#     70                                                           uniprot:(clostridium p47) and identity:0.9
#     69                                                                      uniprot:(protease) identity:0.9
#     69                                                                                                 tp53
#     69                                                                                               myosin
#     69                                                                   uniprot:(reviewed:no) identity:1.0
#     68                                                                                                 luxs
#     67                                                                      uniprot:(protease) identity:0.5
#     66                                                                            bacillus subtilus amylase
#     66                                                  identity:0.9 taxonomy:viridiplantae (9viri) [33090]
#     66  uniprot:(tumor length:[300 to 400] annotation:(type:disease) organism:homo sapiens (human) [9606...
#     65          uniprot:(neuronatin and reviewed:yes and organism:homo sapiens (human) [9606]) identity:0.9
#     64                         uniprot:(reviewed:yes and organism:homo sapiens (human) [9606]) identity:0.5
#     62                                                                                              trypsin
#     61                                                                   uniprot:(reviewed:no) identity:0.5
#     61  uniprot:(tumor annotation:(type:disease) length:[300 to 400] reviewed:yes organism:homo sapiens ...
# ----------------------------------------------------------------------------------------------------
#
#
# User type=browser Namespace=taxonomy
#  Count                                                                    Query
#  11014                                                         solyc05g018060.1
#   4878                                                                        *
#   2193                                                                    human
#   2169                                                             homo sapiens
#   1381                                                            ancestor:9606
#   1016                                                                nishimura
#    938                                                                    mouse
#    795                                                         escherichia coli
#    636                                                             mus musculus
#    625                                                                      rat
#    598                                                            ancestor:2759
#    593                                                 saccharomyces cerevisiae
#    547                                                               ancestor:2
#    497                                         host:homo sapiens (human) [9606]
#    447                                                     arabidopsis thaliana
#    446                                                                 bacteria
#    427                                                            lactobacillus
#    410                                                          ancestor:131567
#    397                                                                    yeast
#    386                                                             complete:yes
#    379                                                              pseudomonas
#    378                                                               bos taurus
#    367                                                    staphylococcus aureus
#    360                                                        bacillus subtilis
#    356                                                                 bacillus
#    350                                                                     homo
#    339                                                   pseudomonas aeruginosa
#    329                                                              clostridium
#    313                                                                      pig
#    303                                                                   bovine
#    302                                                                   e coli
#    292                                                               sus scrofa
#    281                                                           ancestor:10239
#    273                                                                      hba
#    272                                                  drosophila melanogaster
#    269                                                                    fungi
#    269                                                              aspergillus
#    261                           ancestor:escherichia coli (strain k12) [83333]
#    250                                               mycobacterium tuberculosis
#    246                                                        rattus norvegicus
#    244                                                            streptococcus
#    244                            ancestor:corvus corone (carrion crow) [30422]
#    236  ancestor:equisetum telmateia (great horsetail) (equisetum majus) [3260]
#    235                                                             oryza sativa
#    235                                                              arabidopsis
#    232                                                           ancestor:10090
#    228                                                            reference:yes
#    225                                                                  candida
#    223                                                           ancestor:83333
#    221                                                            viridiplantae
#    213                                                                 zea mays
#    212                                                            gallus gallus
#    210                                                              bombyx mori
#    208                                                             streptomyces
#    208                                                          lachnospiraceae
#    199                                                                host:9606
#    196                                                               salmonella
#    194                                                    klebsiella pneumoniae
#    192                              ancestor:unclassified pseudomonas [2583993]
#    190                                                            acinetobacter
#    190                                                              eubacterium
#    189                                                         candida albicans
#    189                                                                    virus
#    189                                                              coronavirus
#    187                                                           staphylococcus
#    183                                                            annotated:yes
#    183                                                             proteome:(*)
#    180                                                            mycobacterium
#    180                                         ancestor:actinobacteria [201174]
#    179                                                                hba whale
#    172                                                               klebsiella
#    172                                                              danio rerio
#    170                                                            ancestor:9605
#    169                                            host:(homo sapiens) and 10249
#    167                                                               prevotella
#    167                                                              glycine max
#    166                                                              bacteroides
#    166                                                             ruminococcus
#    165                                                       enterobacteriaceae
#    165                                                              escherichia
#    165                                                               drosophila
#    164                                                    plasmodium falciparum
#    164                                                               mycoplasma
#    163                                                   caenorhabditis elegans
#    163                                                          bifidobacterium
#    162                                                                   e.coli
#    159                                                           ancestor:33090
#    159                                                          ruminococcaceae
#    159                                                                      dog
#    157                                                           actinobacteria
#    156                                                   streptococcus pyogenes
#    155                                                             enterococcus
#    154                                                                  chicken
#    152                                                                  blautia
#    148                                                                     rice
#    148                                                    mycoplasma pneumoniae
#    148                                                          parabacteroides
#    148                                                             sphingomonas
#    147                                                                    ecoli
#    147                                                            saccharomyces
# ----------------------------------------------------------------------------------------------------
#
#
# User type=browser Namespace=keywords
#  Count                            Query
#   3835                   phosphoprotein
#   3372                           signal
#   2327             alternative splicing
#   2150                     glycoprotein
#   1921                         secreted
#   1846                      acetylation
#   1734                         membrane
#   1187                         immunity
#   1153                     polymorphism
#   1122                   disulfide bond
#   1065                    mitochondrion
#   1044                       cell cycle
#    899                          nucleus
#    888                  ubl conjugation
#    854         transcription regulation
#    693                   oxidoreductase
#    675                    transmembrane
#    645                 disease mutation
#    640              transmembrane helix
#    628               nucleotide-binding
#    627                        transport
#    621                        cytoplasm
#    572                  innate immunity
#    566                    metal-binding
#    562                      atp-binding
#    552                      coiled coil
#    524                    transcription
#    505                 lipid metabolism
#    458                      dna-binding
#    453                        apoptosis
#    435            developmental protein
#    411                      methylation
#    398                    cell membrane
# ...
#     16                                          hepatitis
#     16                                          influenza
#     16                                               apoe
#     16                                   immunodeficiency
#     15                                             dengue
#     15                                             anemia
#     15                                 ulcerative colitis
#     15                                             corona
#     14                                             breast
#     14                                  neurodegenerative
#     14                                     cardiomyopathy
#     14                                             stroke
#     14                         inflammatory bowel disease
# ----------------------------------------------------------------------------------------------------
#
#
# User type=browser Namespace=uniprot
#   Count                                                                               Query
#  480530                                                            organism:9606 and p0c5w0
#  480384                                                            organism:9606 and q96f92
#  480319                                                          organism:9606 and q96l92-4
#  480055                                                            organism:9606 and q96l16
#  478222                                                          organism:9606 and a4qph2-3
#  466571                                                                     replaces:p08107
#  244014                                 organism:9606 and reviewed uniprotunreviewed unprot
#  243663                                                            organism:9606 and q6zst8
#  241624                                                            organism:9606 and p63154
#  240303                                                            organism:9606 and q9h761
#  239970                                                                                   *
#  216998                                                            organism:9606 and q3zb72
#  200486                                                                        reviewed:yes
#  196743                                                            organism:9606 and q99mq1
#  161548                                                          organism:9606 and q9y2s0-2
#  159872                                                            organism:9606 and j3kng9
#  159521                                                            organism:9606 and q5tcc4
#  159013                                                            organism:9606 and a6nhu5
#  158102                                                          organism:9606 and q9nti7-2
#  122400                                                            organism:9606 and q5jua8
#  122093                                                            organism:9606 and q61501
#  121654                                                            organism:9606 and q62282
#  121386                                                            organism:9606 and p35582
#  121270                                                        organism:9606 and a0a0a6yvq5
#  120896                                                            organism:9606 and q63zv0
#  120776                                                            organism:9606 and p21952
#  120705                                                            organism:9606 and p70396
#  115749                                                            organism:9606 and q9jkq4
#  115354                                                            organism:9606 and q91v10
#  115332                                                            organism:9606 and q07424
#  115171                                                          organism:9606 and o70273-3
#  109215                                                            organism:9606 and o08792
#  108984                                                            organism:9606 and q5u4e2
#  108887                                                          organism:9606 and q9wvg6-2
#  108545                                                            organism:9606 and q9erl0
#   93100                                                                                  tm
#   92778                                                                     replaces:p01233
#   82900                                                                     replaces:p01243
#   81496                                                          organism:9606 and q15080-2
#   81297                                                            organism:9606 and q5t6c4
#   78100                                                            organism:9606 and q80su3
#   77575                                                            organism:9606 and q7tsh3
#   59827                                                                      organism:human
#   57434                                                                     replaces:p50224
#   50585                                                                             insulin
#   48196                                                                     replaces:p33155
#   43021                                                                     replaces:p02735
#   40800                                                                     replaces:p00790
#   39394                                                            organism:9606 and o08755
#   39247                                                            organism:9606 and q6pfe1
#   39140                                                            organism:9606 and p48437
#   39007                                                            organism:9606 and q80y82
#   38913                                                            organism:9606 and p50220
#   38629                                                          organism:9606 and a2a935-2
#   38520                                                                     replaces:p62988
#   38344                                                            organism:9606 and p31245
#   38099                                                            organism:9606 and q6pcx8
#   35364                                                                     hemoglobin beta
#   32468                                                                                 p53
#   31314                                                                    accession:p04637
#   27730                                                                          hemoglobin
#   25878                                                                         reviewed:no
#   25279                                                                                egfr
#   25088                                                           ig gamma-1 chain c region
#   24049                                                                    accession:p38398
#   24005                                                                    accession:p01116
#   22200                                         sodium channel protein type 5 subunit alpha
#   22183                                                                    accession:p00533
#   22157                                                                             keratin
#   21839                                                                              ppp1ca
#   21737                                                          organism:9606 and o88286-3
#   21079                                                                               human
#   20354                                                                proteome:up000005640
#   20137  basic fibroblast growth factor receptor 1 and organism:homo sapiens (human) [9606]
#   20081                                                                             slc46a3
#   18813                                                                               actin
#   18736                                                                           myoglobin
#   18392                                                                                tp53
#   18357                                                                               gapdh
#   17961                                                                             albumin
#   17021                                                                                 hba
#   17020                                                                     replaces:p33765
#   16800                                                                           ubiquitin
#   16363                                                                               brca1
#   16214                                                                                 hbb
#   15897                                                                    accession:p60484
#   15816                                               mrna of pka catalytic subunit c-alpha
#   15487                                                                     replaces:q9cza2
#   15395                                                                     replaces:p29312
#   15382                                                                     replaces:p20663
#   14388                                                                                 gfp
#   14363                                                                          calmodulin
#   14283                                                                                ace2
#   13878                                                                            lysozyme
#   13666                                                        prostaglandin g/h synthase 1
#   13565                                                                       organism:fish
#   13539                                                         protein kinase c alpha type
#   13345                                                                        organism:rat
#   13154                                                        prostaglandin g/h synthase 2
#   13104                                                                            thrombin
# ----------------------------------------------------------------------------------------------------
#
#
# User type=browser Namespace=proteomes
#  Count                                           Query
#  12260                                               *
#   9972                                    homo sapiens
#   7864                                           human
#   3381                                   taxonomy:9606
#   2367                                            homo
#   2325                                           mouse
#   2263                                    mus musculus
#   2242                                escherichia coli
#   1793                                    redundant:no
#   1261                        saccharomyces cerevisiae
#   1147                           staphylococcus aureus
#   1026                                          e coli
#    977                                           yeast
#    933                                   reference:yes
#    822                                      bos taurus
#    812                      mycobacterium tuberculosis
#    796                                             rat
#    773                                            9606
#    771                                     arabidopsis
#    753                         drosophila melanogaster
#    741                                  taxonomy:10090
#    735                            arabidopsis thaliana
#    719                                  id:up000005640
#    687      reference:yes and taxonomy:viruses [10239]
#    600                                     homo sapien
#    599                                      drosophila
#    597                       taxonomy:eukaryota [2759]
#    592                                          bovine
#    540                                             mus
#    526                          pseudomonas aeruginosa
#    516                                          rattus
#    514                               bacillus subtilis
#    501                                   gallus gallus
#    454                                     coronavirus
#    450                                            coli
#    441                                          e.coli
#    433                                      sus scrofa
#    433                         acinetobacter baumannii
#    433                                         insulin
#    429                               rattus norvegicus
#    419                          caenorhabditis elegans
#    416                                             hiv
#    415                             helicobacter pylori
#    388                                         e. coli
#    383                                           ecoli
#    381                                     danio rerio
#    376                                    oryza sativa
#    368                                   saccharomyces
#    358                                   columba livia
#    351                                        zea mays
#    341                                  taxonomy:83333
#    340                                   taxonomy:3702
#    337                           plasmodium falciparum
#    334                                            sars
#    325                                   taxonomy:9913
#    318                                             pig
#    315                                            rice
#    314                                   streptococcus
#    311                           klebsiella pneumoniae
#    305                                   organism:9606
#    299                                   mycobacterium
#    297                                candida albicans
#    295                                   taxonomy:7227
#    290                                      salmonella
#    289                                         elegans
#    288                                        bacteria
#    286                                        sars-cov
#    286                        streptococcus pneumoniae
#    285          taxonomy:eukaryota [2759] redundant:no
#    277                                  taxonomy:10116
#    275                                       zebrafish
#    272                                      cerevisiae
#    272                                   lactobacillus
#    268                                 taxonomy:559292
#    264                                        bacillus
#    264                                      e coli k12
#    259                            escherichia coli k12
#    255     reference:yes and taxonomy:eukaryota [2759]
#    255                                      leishmania
#    242                                     homosapiens
#    242                                     pseudomonas
#    240                                         chicken
#    239                                      mycoplasma
#    239              taxonomy:bacteria [2] redundant:no
#    238                                     aspergillus
#    235                                             p53
#    230                                      sars-cov-2
#    229                                             k12
#    228                          streptococcus pyogenes
#    227                                           wheat
#    224                                          rabbit
#    214                                   viridiplantae
#    210                                   taxonomy:9823
#    209                           entamoeba histolytica
#    208                                     glycine max
#    206                           spodoptera frugiperda
#    206                                  id:up000000589
#    205                                             dog
#    204                                      plasmodium
#    203  reference:yes and taxonomy:bacteria [2] atpase
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Programmatic library breakdown

# %%
df_programmatic['Application'].value_counts()
# Out:
# Python Requests      99861490
# Apache-HttpClient    17345401
# Wget                 10590939
# libwww-perl           7771644
# curl                  2513980
# Java                      791
# Name: Application, dtype: int64

# %% [markdown]
# ### Top 100 programmatic queries for each namespace

# %%
save_csv_for_all_namespaces(df_programmatic, 'programmatic')
# Out:
# User type=programmatic Namespace=citations
#  Count                                             Query
#     60                  mappedin:(uniprot:(reviewed:no))
#     54                                                 *
#     41                                     name:analytes
#     37                                       name:values
#     37                                     name:cannabis
#     36                                    name:indicates
#     36                                      name:samples
#     35                                     name:extracts
#     35                                       name:ranges
#     34                                       name:limits
#     32                                  name:metabolites
#     31                                              rpob
#     31                                  name:cannabinoid
#     30                                    name:compounds
#     27                                         name:acid
#     26                                     name:suggests
#     25                                         name:mean
#     25                                        name:study
#     25                                       name:sativa
#     25                                   name:bioaerosol
#     24                                        name:means
#     24                                  name:cannabidiol
#     24                                       name:method
#     23                                     name:requires
#     23                                      name:methods
#     23                                    name:marijuana
#     23                                        name:delta
#     22                                          name:thc
#     22                                  author:ashburner
#     22                                        name:doses
#     22                                        name:novel
#     22                                          name:rat
#     21                                         name:high
#     21                                      name:results
#     21                                     name:agonists
#     21                         title:protein interaction
#     21                                   name:extraction
#     20                                         name:hair
#     20                                       name:direct
#     20                                    name:determine
#     20                                        name:vitro
#     20                                          name:key
#     20                                       name:plasma
#     19                                      name:overall
#     19                                         name:aims
#     19                                              lldd
#     19                                        name:urine
#     19                                 name:experimental
#     19                                   name:identified
#     19                                          name:due
#     18                                      name:windows
#     18                                         name:hemp
#     18                                     name:decrease
#     18                                        name:avoid
#     18                                     name:identify
#     18                                    name:knowledge
#     18                                       name:liquid
#     18                                      name:opiates
#     18                                     name:presents
#     18                                       name:sample
#     18                                        name:human
#     18                                   name:background
#     18                                        name:acute
#     17                                         name:test
#     17                                       name:become
#     17                                          name:low
#     17                                         name:lack
#     17                                          name:use
#     17                                      name:purpose
#     17                                         name:bias
#     17                                      name:cocaine
#     17                                      name:present
#     17                                         name:μg/l
#     17                                        name:prior
#     17                                    name:specimens
#     16                                 name:cannabinoids
#     16                                    name:different
#     16                                        name:blood
#     16                                       name:assays
#     16                                 name:inflammatory
#     16                                         name:cell
#     16                            name:phytocannabinoids
#     16                                      name:chronic
#     16                                         name:oral
#     16                                       name:curves
#     16  kuopio ischaemic heart disease risk factor study
#     16                                        name:daily
#     16                                       name:linear
#     16                                        name:whole
#     16                                      name:natural
#     16                                   name:functional
#     16                                        name:phase
#     16                                     name:compound
#     16                                       name:intake
#     16                                     name:olivetol
#     16                                      name:reports
#     16                                      name:medical
#     16                                   name:scientific
#     15                                     name:diseases
#     15                                     name:evaluate
# ----------------------------------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=locations
#  Count                         Query
#     37                 name:cannabis
#     36                 name:analytes
#     36                   name:values
#     34                   name:ranges
#     34                name:indicates
#     33                 name:extracts
#     32              name:metabolites
#     31              name:cannabinoid
#     31                  name:samples
#     30                name:compounds
#     28                   name:limits
#     27                     name:acid
#     25              name:cannabidiol
#     25                   name:sativa
#     25                     name:mean
#     25                    name:study
#     25                 name:suggests
#     25                   name:method
#     24               name:bioaerosol
#     23                    name:delta
#     23                    name:novel
#     23                name:marijuana
#     23                 name:requires
#     23                  name:methods
#     22                      name:rat
#     22                      name:thc
#     21               name:extraction
#     21                   name:direct
#     21                     name:high
#     21                  name:results
#     20                    name:vitro
#     20                     name:hair
#     20                      name:key
#     20                      name:due
#     20                   name:plasma
#     19                 name:identify
#     19                  name:overall
#     19                name:determine
#     19             name:experimental
#     19                   name:liquid
#     19                    name:urine
#     19               name:identified
#     18                     name:hemp
#     18               name:background
#     18                     name:aims
#     18                name:knowledge
#     18                 name:decrease
#     18                  name:purpose
#     18                    name:avoid
#     18                    name:acute
#     18                   name:sample
#     18                    name:human
#     17                      name:low
#     17                     name:bias
#     17                   name:become
#     17                    name:total
#     17                     name:oral
#     17                   name:linear
#     17                     name:test
#     17                     name:μg/l
#     17                     name:lack
#     17                    name:means
#     17                    name:prior
#     17               name:functional
#     17               name:scientific
#     17                      name:use
#     17                name:different
#     17                  name:cocaine
#     17                    name:daily
#     16                name:specimens
#     16                 name:evaluate
#     16               name:individual
#     16                    name:range
#     16                 name:absolute
#     16                    name:phase
#     16               name:assessment
#     16                  name:medical
#     16             name:cannabinoids
#     16            name:cell membrane
#     16                  name:opiates
#     16             name:inflammatory
#     16                  name:natural
#     16          name:golgi apparatus
#     16                 name:olivetol
#     16                   name:median
#     16                     name:cell
#     16                 name:compound
#     16                    name:ng/ml
#     16                    name:blood
#     16                  name:discuss
#     16                    name:whole
#     16                   name:intake
#     16                  name:present
#     16                    name:first
#     16        name:phytocannabinoids
#     16                  name:chronic
#     16  name:δ9-tetrahydrocannabinol
#     15                  name:enzymes
#     15                 name:multiple
#     15                   name:public
# ----------------------------------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=uniparc
#  Count                                                                                                Query
#   6906  checksum:d3767ab49010536b or checksum:3df027273d082e91 or checksum:292c99cf770599ef or checksum:...
#   6143  checksum:1370bf3e72bb84b3 or checksum:8fcc902def411fe8 or checksum:fb11e699881ad39f or checksum:...
#   6060                                                                                        no data found
#   4557  checksum:e2723416d5e4b880 or checksum:a34f0ff1894c0a7d or checksum:b24058ccae580633 or checksum:...
#   4319  checksum:3a0d391deffa5275 or checksum:bf260c51838b077f or checksum:5f7278336e54e32e or checksum:...
#   4101                                                                                traes_2al_f750a006f.1
#   3526  checksum:7f5d099ff1455d7b or checksum:4db3656fbcf4d1b7 or checksum:955b60c9a8572e6f or checksum:...
#   3343  checksum:5c6a20207f69ce2d or checksum:094b02b47697e870 or checksum:37081e9b249b28ee or checksum:...
#   3253  checksum:e350dbcab8d5aa9d or checksum:bd9c81a40323d765 or checksum:37d527a087db7411 or checksum:...
#   3215  checksum:a2f10f664bb01080 or checksum:791024aca4c6ae42 or checksum:223f47fdb13edcf7 or checksum:...
#   3131  checksum:ffae3f9b6e379d6c or checksum:d1b3e74aadd76d2e or checksum:24291253717b6954 or checksum:...
#   3104  checksum:313cadc0d5b3842a or checksum:300fba0ca9a9908e or checksum:29f1a44e22833c5c or checksum:...
#   2847  checksum:01d7b932a20a5cef or checksum:4403ff51d2e9891b or checksum:ec74e0031e961eea or checksum:...
#   2724  checksum:69902e52270db2df or checksum:f17103e80ebb3474 or checksum:59bba3a37aa250d9 or checksum:...
#   2698  checksum:5f96aa3ca1743f74 or checksum:5533f28ffc36e104 or checksum:dd5688a6f72696a7 or checksum:...
#   2674  checksum:98e42e725272c7d1 or checksum:ee1178180abc9d45 or checksum:8852b88e9b4adafd or checksum:...
#   2473  checksum:9d955844dac47619 or checksum:354939b2a5c4fedf or checksum:6c2453326c51bb2d or checksum:...
#   2453  checksum:ec744aed416be1c2 or checksum:71c8e0dc70dfb051 or checksum:e7b818b026e16378 or checksum:...
#   2403  checksum:4fde361bd76cc485 or checksum:d96a6802a486ebb0 or checksum:86ad632bdf743b24 or checksum:...
#   2358  checksum:a2d7ecb944e29332 or checksum:d4b100a90dc3ece7 or checksum:14852442607537f3 or checksum:...
#   2186                                                                                             aml99881
#   2022  checksum:5d6134ca95fb1698 or checksum:a4d88dc5bd9f1d95 or checksum:3286e760c6b69d3c or checksum:...
#   2012  checksum:dfd352ed63e0cd06 or checksum:69902e52270db2df or checksum:f17103e80ebb3474 or checksum:...
#   2011  checksum:fb239526a49bd4ad or checksum:ab798e4aae4d9a42 or checksum:8fbe127566a4caa4 or checksum:...
#   1949  checksum:69902e52270db2df or checksum:f17103e80ebb3474 or checksum:59bba3a37aa250d9 or checksum:...
#   1889  checksum:3c79ec5169f6fbec or checksum:d3e826164df596f5 or checksum:1c138a774bc9ba50 or checksum:...
#   1865                  checksum:a2f10f664bb01080 or checksum:791024aca4c6ae42 or checksum:223f47fdb13edcf7
#   1822  checksum:d3767ab49010536b or checksum:3df027273d082e91 or checksum:5c6a20207f69ce2d or checksum:...
#   1815  checksum:23e734b2a0775cb5 or checksum:bffe49fb5ac59bea or checksum:fc845ab2f863806e or checksum:...
#   1782  checksum:3a0d391deffa5275 or checksum:bf260c51838b077f or checksum:5f7278336e54e32e or checksum:...
#   1732                  checksum:126a9134e837b170 or checksum:d9737fdec08bfda5 or checksum:c591ed0ffa7e4098
#   1689  checksum:c77a0ecce98e1ca1 or checksum:aebe6d0731fa2d60 or checksum:796efc808ec98983 or checksum:...
#   1649  checksum:64ea75999d7c6314 or checksum:1d33b66ca7109b03 or checksum:4e56b90e26c58a49 or checksum:...
#   1636  checksum:091bbcaa48789379 or checksum:8646fc91fde020d3 or checksum:491accc2f8d060de or checksum:...
#   1587  checksum:47332691a771141f or checksum:32033afd6028faed or checksum:52ec089e5628de50 or checksum:...
#   1560                                                                            checksum:c0dfcc4904c10b31
#   1491  checksum:e350dbcab8d5aa9d or checksum:bd9c81a40323d765 or checksum:37d527a087db7411 or checksum:...
#   1480  checksum:21fe96169f46ee87 or checksum:2bea3e4c43c36ddf or checksum:2bea2c7543c3462f or checksum:...
#   1465                  checksum:141f063018ceaf5d or checksum:b1a10705886d64c0 or checksum:92974aa3a58b62c0
#   1431  checksum:60884f849611e401 or checksum:5573d7e52c666cd2 or checksum:4fdb40201066eebd or checksum:...
#   1413  checksum:e2df9a05edb007ce or checksum:b6a1d86e8d2842c3 or checksum:de02b6c65dd9a933 or checksum:...
#   1405  checksum:195e130d0be0ec29 or checksum:a3b5cb3eed0fbfe4 or checksum:21f3b180d8bca4dd or checksum:...
#   1387  checksum:c31ae2d8c7a3248c or checksum:70e84efb3ae8465d or checksum:f248f4b24c0038fe or checksum:...
#   1384                                                                                traes_1al_00e379eff.2
#   1347  checksum:06f22b4f0ca7d1b2 or checksum:5b49d48f3526714a or checksum:6afb9d81c66d6908 or checksum:...
#   1331  checksum:cd737758e60ac028 or checksum:1d103a4c4fb00959 or checksum:a85304bdec8d774d or checksum:...
#   1316  checksum:a52d78a4bbf006fa or checksum:72c4107bb26513a2 or checksum:df7aef24380a0fd9 or checksum:...
#   1288  checksum:1d103a4c4fb00959 or checksum:a85304bdec8d774d or checksum:6ec45d947620f20a or checksum:...
#   1276  checksum:5c3ef20b2bbfc624 or checksum:ee765fb371d9c96e or checksum:de028fa33c7c00b6 or checksum:...
#   1239                                               checksum:6d72f3a005c66e2a or checksum:4231101f9ce8f696
#   1217  checksum:5d6134ca95fb1698 or checksum:a4d88dc5bd9f1d95 or checksum:3286e760c6b69d3c or checksum:...
#   1185  checksum:c1e8383b15154c1e or checksum:05e57c9f44758c9a or checksum:70d560f3832c6268 or checksum:...
#   1184  checksum:e1ce016cdd00773e or checksum:dfffac88164c50ba or checksum:6295979183e13fcb or checksum:...
#   1138  checksum:cd07ae3ebf5fc97f or checksum:768b6ae41ad66669 or checksum:eff1c8fb2bb0256e or checksum:...
#   1134                                                                                           a0a2r6ud96
#   1115  checksum:3bbb97030148f84c or checksum:03ab4e97ac2ff56a or checksum:58f650a52ce4dca0 or checksum:...
#   1108  checksum:62d9a2c46d82aba3 or checksum:d12b0ee790c9c972 or checksum:538bb4aee621b7d1 or checksum:...
#   1075  checksum:df7aef24380a0fd9 or checksum:97825b8135309dc1 or checksum:5c6a20207f69ce2d or checksum:...
#   1042  checksum:62d9a2c46d82aba3 or checksum:d12b0ee790c9c972 or checksum:538bb4aee621b7d1 or checksum:...
#   1039  checksum:e2723416d5e4b880 or checksum:a34f0ff1894c0a7d or checksum:b24058ccae580633 or checksum:...
#   1030  checksum:0ad73b555062c8b4 or checksum:da885ab6f3a1de47 or checksum:b2d9ba1de27a44d0 or checksum:...
#   1030  checksum:8927aeed18dba465 or checksum:03aa6752ef7d7492 or checksum:b196833c7df77fbb or checksum:...
#   1027  checksum:711f3dcf599643db or checksum:e76fc5a30fa890f2 or checksum:2517015e2d2989c6 or checksum:...
#   1027  checksum:0af93648017b65e5 or checksum:ec744aed416be1c2 or checksum:71c8e0dc70dfb051 or checksum:...
#   1018  checksum:e72b7bb5f3faa515 or checksum:5bbc3a23623d94d9 or checksum:c333641abc9da1a1 or checksum:...
#   1006                  checksum:e89f1b145ef40710 or checksum:7949762ae2c0119c or checksum:544ef234135044b9
#    980  checksum:f15037e750843ca2 or checksum:e850535d1233cdac or checksum:f6f0bdbea9fdb2a6 or checksum:...
#    977  checksum:1e634b7bbbfbac6a or checksum:75b88cde79e9b5ae or checksum:1b925129d4f031a3 or checksum:...
#    973  checksum:55d0becb9e99340f or checksum:55517da6722b98ab or checksum:efef562ebb89049e or checksum:...
#    962  checksum:b21d8bd8bea8c20a or checksum:8688f8209240dc95 or checksum:73813362c5bcd987 or checksum:...
#    951  checksum:e2723416d5e4b880 or checksum:a34f0ff1894c0a7d or checksum:b24058ccae580633 or checksum:...
#    950  checksum:b29c79f4bb6c6a63 or checksum:cca31f3fbca751a7 or checksum:313cadc0d5b3842a or checksum:...
#    947  checksum:5f96aa3ca1743f74 or checksum:5533f28ffc36e104 or checksum:dd5688a6f72696a7 or checksum:...
#    939  checksum:a65ea28e58ec31dc or checksum:1c3b15d2e556c547 or checksum:3b40f42bc4ae611c or checksum:...
#    933  checksum:b793a53f05dba475 or checksum:12e53a401b99f39a or checksum:44a153d11e840c50 or checksum:...
#    917  checksum:1736f551612f2bf1 or checksum:2951a87de6ffcc3f or checksum:e3bde7b6ab6124d4 or checksum:...
#    898                                               checksum:206629b327c434ae or checksum:a573a50fd86ccb49
#    854                                                                            checksum:f642080fbeebea33
#    847  checksum:c6f6fa9f13e60ade or checksum:928c2d5c34003b75 or checksum:c17eff12ac85f58a or checksum:...
#    845  checksum:201afe8effd816dd or checksum:f9ce3480a29adccd or checksum:5042d692c760496e or checksum:...
#    832                                                                                               a2rgl9
#    828  checksum:3a71381f87c8bfe7 or checksum:05bde8187c370c42 or checksum:b318be3c7633b11c or checksum:...
#    804  checksum:ffae3f9b6e379d6c or checksum:d1b3e74aadd76d2e or checksum:24291253717b6954 or checksum:...
#    798  checksum:62d9a2c46d82aba3 or checksum:d12b0ee790c9c972 or checksum:538bb4aee621b7d1 or checksum:...
#    795  checksum:855b98bfd8d77fde or checksum:52f7159836ec1d6f or checksum:5a8ed8f616532350 or checksum:...
#    791  checksum:a90f322e52e5c721 or checksum:70fe4c8af43a7655 or checksum:6a8b51faf596da08 or checksum:...
#    786  checksum:dd72af0e180a948a or checksum:c0e1d5b001ae25ce or checksum:49671a822651b3c1 or checksum:...
#    784  checksum:841afc582b4a1187 or checksum:bc14500263d2a313 or checksum:3144494a3a5a2d7c or checksum:...
#    783  checksum:aae57144e82f3c99 or checksum:7f5d099ff1455d7b or checksum:4db3656fbcf4d1b7 or checksum:...
#    780  checksum:7e005bce5ef393c7 or checksum:8cd8b5996ed436de or checksum:1f53951f294edf9f or checksum:...
#    778  checksum:fa269a813f2ef3ee or checksum:d3e7e8006535ff8b or checksum:20423e5830b4d63b or checksum:...
#    778  checksum:eb78a3ba1ce1fefc or checksum:085fad6461c0461d or checksum:72fa2fdbbafd16b1 or checksum:...
#    773  checksum:4f48c0e2c63a59af or checksum:8e9c9eb89e779ff9 or checksum:0c3c24f1e89fe15a or checksum:...
#    760  checksum:b4e58dcbde3cb63f or checksum:3073497e2f8753ac or checksum:e9413af24a486750 or checksum:...
#    759  checksum:23f3901cbe5563d8 or checksum:346da4f3b69af6e2 or checksum:74d88b338a54705e or checksum:...
#    746                                               checksum:033663e726f1e219 or checksum:0661d3e1e9a4f980
#    743  checksum:0ae6ef2d7b667aca or checksum:f4894c249e8cc8c0 or checksum:54de3776bfab8b48 or checksum:...
#    724  checksum:5d6134ca95fb1698 or checksum:a4d88dc5bd9f1d95 or checksum:3286e760c6b69d3c or checksum:...
#    711  checksum:95d1e2ef9c38c603 or checksum:23d234ee61dfe2cc or checksum:a60a8d18a14c04de or checksum:...
#    711  checksum:66ca9e637c87a2d9 or checksum:793fa897d2a1820b or checksum:bf35ad60e1573630 or checksum:...
# ----------------------------------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=database
#  Count                         Query
#     39                             *
#     38                 name:cannabis
#     34                   name:values
#     33                 name:analytes
#     32              name:metabolites
#     31              name:cannabinoid
#     31                 name:extracts
#     30                name:compounds
#     29                   name:ranges
#     29                name:indicates
#     28                  name:samples
#     27                     name:acid
#     26                     name:mean
#     25                   name:sativa
#     25                   name:limits
#     25                    name:study
#     25                   name:method
#     25              name:cannabidiol
#     25                 name:suggests
#     24               name:bioaerosol
#     23                    name:novel
#     23                    name:delta
#     23                  name:methods
#     23                 name:requires
#     22                      name:rat
#     22                      name:thc
#     22                name:marijuana
#     21                  name:results
#     21                   name:direct
#     21                     name:high
#     21               name:extraction
#     20                    name:urine
#     20                    name:vitro
#     20                     name:hair
#     20                      name:key
#     20                   name:plasma
#     19                   name:sample
#     19                    name:acute
#     19             name:experimental
#     19                   name:liquid
#     19                 name:identify
#     19                  name:overall
#     19               name:identified
#     19                name:determine
#     19                      name:due
#     19                     name:aims
#     18                name:knowledge
#     18                     name:hemp
#     18                    name:avoid
#     18                  name:purpose
#     18                 name:decrease
#     18                    name:human
#     18               name:background
#     18                  name:cocaine
#     17                      name:low
#     17               name:scientific
#     17                      name:use
#     17                     name:lack
#     17               name:functional
#     17                   name:become
#     17                   name:linear
#     17                 name:absolute
#     17                    name:prior
#     17                name:different
#     17                    name:daily
#     17                     name:test
#     17                     name:bias
#     16                    name:whole
#     16                    name:phase
#     16  name:δ9-tetrahydrocannabinol
#     16             name:cannabinoids
#     16                    name:ng/ml
#     16                    name:range
#     16                    name:blood
#     16                  name:present
#     16                  name:medical
#     16                 name:evaluate
#     16             name:inflammatory
#     16                  name:opiates
#     16                     name:cell
#     16                 name:olivetol
#     16               name:individual
#     16                  name:discuss
#     16                  name:natural
#     16                    name:total
#     16        name:phytocannabinoids
#     16                 name:compound
#     16                  name:chronic
#     16                   name:intake
#     16               name:assessment
#     16                     name:μg/l
#     16                name:specimens
#     16                    name:first
#     16                     name:oral
#     16                   name:median
#     15                 name:frequent
#     15               name:experiment
#     15                  name:reports
#     15                 name:multiple
#     15                name:molecular
# ----------------------------------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=uniref
#  Count                                                                                                Query
#  12675                                                                                   id:uniref90_q6k043
#    860                                                                                   id:uniref50_q6gqt5
#    459                                                                                   id:uniref50_q6k043
#    177                                                                                        member:q03063
#    156                                                                                                    *
#    149                                  uniprot:(ec:7.3.2.1 taxonomy:bacteria and reviewed:no) identity:0.5
#    120                                                                         uniprot:(*) and identity:1.0
#    115                                uniprot:(ec:1.1.1.157 taxonomy:bacteria and reviewed:no) identity:0.5
#    112                                                                                   id:uniref50_p01174
#    110                                                                         uniprot:(*) and identity:0.9
#     91                                                                         uniprot:(*) and identity:0.5
#     88                  uniprot:(name:cobyric acid synthase taxonomy:bacteria and reviewed:no) identity:0.5
#     83                                                                             uniprot:(*) identity:0.9
#     82                                                  uniprot:(taxonomy:viruses [10239]) and identity:0.5
#     82                                                                                   id:uniref50_p01173
#     78                                                                             uniprot:(*) identity:1.0
#     74                                                               uniprot:(reviewed:no) and identity:0.5
#     73                                 uniprot:(ec:3.6.3.27 taxonomy:bacteria and reviewed:no) identity:0.5
#     69  uniprot:(name:2-hydroxyhepta-2,4-diene-1,7-dioate isomerase taxonomy:bacteria and reviewed:no) i...
#     63                                                               uniprot:(reviewed:no) and identity:1.0
#     60                    uniprot:(name:citrate transporter taxonomy:bacteria and reviewed:no) identity:0.5
#     60                                  uniprot:(ec:2.7.4.1 taxonomy:bacteria and reviewed:no) identity:0.5
#     59                                    uniprot:(name:na taxonomy:bacteria and reviewed:yes) identity:0.9
#     59                                                                             uniprot:(*) identity:0.5
#     59                                                                   uniprot:(reviewed:no) identity:1.0
#     58                                     uniprot:(name:na taxonomy:bacteria and reviewed:no) identity:0.5
#     58                                  uniprot:(ec:2.1.2.9 taxonomy:bacteria and reviewed:no) identity:0.5
#     58                                  uniprot:(ec:2.7.7.7 taxonomy:bacteria and reviewed:no) identity:0.5
#     57                     uniprot:(name:l-lactate permease taxonomy:bacteria and reviewed:no) identity:0.5
#     57                                                              uniprot:(reviewed:yes) and identity:1.0
#     56                                  uniprot:(ec:4.2.3.3 taxonomy:bacteria and reviewed:no) identity:0.5
#     56                                 uniprot:(ec:2.7.7.6 taxonomy:bacteria and reviewed:yes) identity:0.9
#     55                                 uniprot:(ec:3.6.3.17 taxonomy:bacteria and reviewed:no) identity:0.5
#     54                                 uniprot:(ec:3.4.11.5 taxonomy:bacteria and reviewed:no) identity:0.5
#     54                                  uniprot:(ec:3.5.2.6 taxonomy:bacteria and reviewed:no) identity:0.5
#     53       uniprot:(name:manganese transport protein mnth taxonomy:bacteria and reviewed:no) identity:0.5
#     53    uniprot:(name:cobalamin biosynthesis protein cobg taxonomy:bacteria and reviewed:no) identity:0.5
#     53  uniprot:(name:geranyl-diphosphate diphosphate-lyase [(3s)-linalool-forming] taxonomy:bacteria an...
#     52                       uniprot:(name:uridylate kinase taxonomy:bacteria and reviewed:no) identity:0.5
#     52                                      uniprot:(organism:homo sapiens (human) [9606]) and identity:1.0
#     52                                 uniprot:(ec:3.1.3.16 taxonomy:bacteria and reviewed:no) identity:0.5
#     52                                  uniprot:(ec:7.6.2.7 taxonomy:bacteria and reviewed:no) identity:0.5
#     51                     uniprot:(name:cobalamin synthase taxonomy:bacteria and reviewed:no) identity:0.5
#     51                                  uniprot:(ec:2.7.3.9 taxonomy:bacteria and reviewed:no) identity:0.5
#     51  uniprot:(name:(2e,6e)-farnesyl-diphosphate diphosphate-lyase [(s)-beta-bisabolene-forming] taxon...
#     51                                                                                        upi00053b150b
#     51                  uniprot:(name:ethanolamine permease taxonomy:bacteria and reviewed:no) identity:0.5
#     50                                 uniprot:(ec:4.4.1.16 taxonomy:bacteria and reviewed:no) identity:0.5
#     50  uniprot:(name:phosphoribosyl-dephospho-coa transferase taxonomy:bacteria and reviewed:no) identi...
#     50                                  uniprot:(ec:7.5.2.1 taxonomy:bacteria and reviewed:no) identity:0.5
#     50  uniprot:(name:segregation and condensation protein a taxonomy:bacteria and reviewed:no) identity...
#     49                                  uniprot:(ec:2.7.7.6 taxonomy:bacteria and reviewed:no) identity:0.5
#     49                                                                  uniprot:(proteome:(*)) identity:1.0
#     49  uniprot:(name:(2e,6e)-farnesyl-diphosphate diphosphate-lyase [(e)-gamma-bisabolene-forming] taxo...
#     49                                  uniprot:(ec:1.8.1.8 taxonomy:bacteria and reviewed:no) identity:0.5
#     49                                      uniprot:(organism:homo sapiens (human) [9606]) and identity:0.5
#     49                                                                                               a0ncq2
#     49  uniprot:(name:sulfate transport system permease protein cyst taxonomy:bacteria and reviewed:no) ...
#     49  uniprot:(name:chromosomal replication initiator protein dnaa taxonomy:bacteria and reviewed:no) ...
#     49                                uniprot:(ec:2.4.1.301 taxonomy:bacteria and reviewed:no) identity:0.5
#     48               uniprot:(name:lipoate-protein ligase a taxonomy:bacteria and reviewed:no) identity:0.5
#     48                                                                                         identity:0.5
#     48                                      uniprot:(organism:homo sapiens (human) [9606]) and identity:0.9
#     47                                 uniprot:(ec:1.6.99.5 taxonomy:bacteria and reviewed:no) identity:0.5
#     47            uniprot:(name:sulfur carrier protein this taxonomy:bacteria and reviewed:no) identity:0.5
#     47                      uniprot:(name:adenylate cyclase taxonomy:bacteria and reviewed:no) identity:0.5
#     47              uniprot:(name:d-galactonate transporter taxonomy:bacteria and reviewed:no) identity:0.5
#     47                                  uniprot:(ec:3.1.6.1 taxonomy:bacteria and reviewed:no) identity:0.5
#     47                                 uniprot:(ec:3.6.1.17 taxonomy:bacteria and reviewed:no) identity:0.5
#     47                      uniprot:(name:xanthine permease taxonomy:bacteria and reviewed:no) identity:0.5
#     46             uniprot:(name:arabinose-proton symporter taxonomy:bacteria and reviewed:no) identity:0.5
#     46                                 uniprot:(ec:3.1.4.53 taxonomy:bacteria and reviewed:no) identity:0.5
#     45  uniprot:(name:2-oxo-hepta-3-ene-1,7-dioic acid hydratase taxonomy:bacteria and reviewed:no) iden...
#     45  uniprot:(name:lipopolysaccharide heptosyltransferase iii taxonomy:bacteria and reviewed:no) iden...
#     45  uniprot:(name:cytosine/purine/uracil/thiamine/allantoin permease family protein taxonomy:bacteri...
#     45                                 uniprot:(ec:5.99.1.3 taxonomy:bacteria and reviewed:no) identity:0.5
#     45                                 uniprot:(ec:1.7.99.4 taxonomy:bacteria and reviewed:no) identity:0.5
#     45       uniprot:(name:glycerol-3-phosphate transporter taxonomy:bacteria and reviewed:no) identity:0.5
#     45  uniprot:(name:methionine abc transporter permease protein taxonomy:bacteria and reviewed:no) ide...
#     45  uniprot:(name:anaerobic dimethyl sulfoxide reductase chain b taxonomy:bacteria and reviewed:no) ...
#     45                            uniprot:(name:thioredoxin taxonomy:bacteria and reviewed:no) identity:0.5
#     45                                 uniprot:(ec:1.8.4.11 taxonomy:bacteria and reviewed:no) identity:0.5
#     45  uniprot:(name:lipid a biosynthesis (kdo) 2-(lauroyl)-lipid iva acyltransferase taxonomy:bacteria...
#     45        uniprot:(name:biotin carboxyl carrier protein taxonomy:bacteria and reviewed:no) identity:0.5
#     44            uniprot:(name:l-rhamnose-proton symporter taxonomy:bacteria and reviewed:no) identity:0.5
#     44        uniprot:(name:formate hydrogenlyase subunit 7 taxonomy:bacteria and reviewed:no) identity:0.5
#     44  uniprot:(name:xanthine/uracil/thiamine/ascorbate permease family protein taxonomy:bacteria and r...
#     44  uniprot:(name:mannose-1-phosphate guanylyltransferase taxonomy:bacteria and reviewed:no) identit...
#     44    uniprot:(name:glycerol uptake facilitator protein taxonomy:bacteria and reviewed:no) identity:0.5
#     44                                 uniprot:(ec:3.1.3.89 taxonomy:bacteria and reviewed:no) identity:0.5
#     43  uniprot:(name:succinate dehydrogenase cytochrome b-556 subunit taxonomy:bacteria and reviewed:no...
#     43                                uniprot:(ec:2.7.1.201 taxonomy:bacteria and reviewed:no) identity:0.5
#     43                            uniprot:(name:dna primase taxonomy:bacteria and reviewed:no) identity:0.5
#     43   uniprot:(name:malonate decarboxylase alpha subunit taxonomy:bacteria and reviewed:no) identity:0.5
#     43  uniprot:(name:biotin carboxyl carrier protein of acetyl-coa carboxylase taxonomy:bacteria and re...
#     43  uniprot:(name:trk system potassium uptake protein trka taxonomy:bacteria and reviewed:no) identi...
#     43                                                              uniprot:(reviewed:yes) and identity:0.9
#     42  uniprot:(name:(2e,6e)-farnesyl-diphosphate diphosphate-lyase [(e)-alpha-bisabolene-forming] taxo...
#     42  uniprot:(name:(2e,6e)-farnesyl-diphosphate diphosphate-lyase [(e)-gamma-bisabolene-forming] taxo...
#     42                                uniprot:(ec:2.1.3.15 taxonomy:bacteria and reviewed:yes) identity:0.9
# ----------------------------------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=taxonomy
#  Count                                                                    Query
#   2073                                                                 zea mays
#   2034                                                   <built-in function id>
#   1474                                           triticum turgidum subsp. durum
#   1214                                                            daphnia magna
#   1025                                     aegilops tauschii subsp. strangulata
#    699                                                     uncultured bacterium
#    614                                                      drosophila simulans
#    520                                                        triticum aestivum
#    490                                                 drosophila pseudoobscura
#    488                                                             glycine soja
#    487                                                               sus scrofa
#    454                     burkholderia pseudomallei (pseudomonas pseudomallei)
#    421                                           hordeum vulgare subsp. vulgare
#    401                                                  drosophila melanogaster
#    376                                                  rhizophagus irregularis
#    368                                                       gossypium hirsutum
#    363                                                        nicotiana tabacum
#    361                                             oryza sativa subsp. japonica
#    351                                                           vitis vinifera
#    342                                                   burkholderia ubonensis
#    308                                                          artemisia annua
#    302                                                     noccaea caerulescens
#    293                                                  aureobasidium pullulans
#    285                                                              hucho hucho
#    283                                               trichinella pseudospiralis
#    271  rhizophagus irregularis (strain daom 181602 / daom 197198 / mucl 43194)
#    265                                                              salmo salar
#    261                                                      nicotiana attenuata
#    259                                                         trifolium medium
#    257                                                         lates calcarifer
#    250                                                      medicago truncatula
#    250                                                          capsicum annuum
#    249                                                        panicum miliaceum
#    243                                                     arabidopsis thaliana
#    241                                                       gossypium arboreum
#    240                                                           macaca mulatta
#    229                                                       drosophila obscura
#    228                                                      macrostomum lignano
#    222                                                          ursus maritimus
#    220                                                   caenorhabditis remanei
#    209                                                             homo sapiens
#    208                                                          pan troglodytes
#    208                                                      callorhinchus milii
#    205                                                         nelumbo nucifera
#    204                                       actinidia chinensis var. chinensis
#    199                                                           rosa chinensis
#    198                                                       aquilegia coerulea
#    195                                                        aegilops tauschii
#    190                                                 trichinella zimbabwensis
#    187                                                          theobroma cacao
#    185                                                            juglans regia
#    185                                                        drosophila yakuba
#    183                                                   caenorhabditis elegans
#    183                                                     nicotiana sylvestris
#    179                                                 bos indicus x bos taurus
#    179                                                       callithrix jacchus
#    174                                                      macaca fascicularis
#    172                                                               bos taurus
#    168                                                   physeter macrocephalus
#    167                                                      phoenix dactylifera
#    166                                                          bacillus cereus
#    164                                                           lygus hesperus
#    164                                                       trichinella sp. t9
#    164                                                       anthurium amnicola
#    158                                                         folsomia candida
#    158                                                       trichinella sp. t6
#    156                                                             capra hircus
#    156                                                    delphinapterus leucas
#    155                                                     bactrocera latifrons
#    151                                                              glycine max
#    148                                                             mus musculus
#    148                                                    fundulus heteroclitus
#    146                                                                      p53
#    146                                                       alligator sinensis
#    145                                                         ursus americanus
#    145                                                        capsicum baccatum
#    145                                               vigna radiata var. radiata
#    143                                                       trifolium pratense
#    143                                                    drosophila subobscura
#    139                                                             populus alba
#    139                                                          cicer arietinum
#    139                                                          mucuna pruriens
#    138                                                          oryzias latipes
#    138                                          saimiri boliviensis boliviensis
#    138                                                          triticum urartu
#    138                                                       trichinella sp. t8
#    136                                                      gossypium raimondii
#    136                                       cinnamomum micranthum f. kanehirae
#    135                                                 cebus capucinus imitator
#    135                                                    klebsiella pneumoniae
#    135                                              strongyloides venezuelensis
#    133                                                      trichinella nelsoni
#    132                                                       tursiops truncatus
#    132                                                        hortaea werneckii
#    131                                                             oryza nivara
#    130                                                  austrofundulus limnaeus
#    130                                               dichanthelium oligosanthes
#    129                                                             pongo abelii
#    129                                                  rhinopithecus roxellana
#    128                                                       trichinella papuae
# ----------------------------------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=keywords
#  Count                         Query
#    597                             *
#     40                 name:analytes
#     38                 name:cannabis
#     37                   name:values
#     36                name:indicates
#     35                  name:samples
#     34                   name:ranges
#     34                 name:extracts
#     31              name:cannabinoid
#     31              name:metabolites
#     30                name:compounds
#     29                   name:limits
#     26                     name:mean
#     26                     name:acid
#     26                 name:suggests
#     25                   name:method
#     25                    name:study
#     25              name:cannabidiol
#     24               name:bioaerosol
#     24                   name:sativa
#     23                name:marijuana
#     23                  name:methods
#     23                 name:requires
#     23                    name:novel
#     22                    name:delta
#     22                      name:thc
#     21               name:extraction
#     21                     name:high
#     21                  name:results
#     21                      name:key
#     21                      name:rat
#     20                   name:direct
#     20                   name:plasma
#     20                      name:due
#     20                     name:hair
#     20                    name:vitro
#     19                    name:urine
#     19                    name:means
#     19                 name:identify
#     19               name:identified
#     19             name:experimental
#     19                    name:acute
#     19                   name:liquid
#     19                    name:doses
#     18                    name:avoid
#     18                 name:decrease
#     18                   name:sample
#     18                     name:aims
#     18                  name:overall
#     18                     name:hemp
#     18               name:background
#     18                name:knowledge
#     18                    name:human
#     18                  name:purpose
#     18                name:determine
#     17                 name:agonists
#     17                  name:present
#     17               name:scientific
#     17                      name:low
#     17                name:different
#     17                     name:bias
#     17                 name:absolute
#     17               name:functional
#     17                   name:become
#     17                   name:linear
#     17                     name:lack
#     17                    name:prior
#     17                      name:use
#     17                     name:test
#     17                  name:cocaine
#     17                    name:daily
#     16                   name:intake
#     16        name:phytocannabinoids
#     16                  name:medical
#     16             name:cannabinoids
#     16                  name:natural
#     16                 name:compound
#     16               name:assessment
#     16                     name:cell
#     16                 name:evaluate
#     16                  name:discuss
#     16                    name:blood
#     16                     name:μg/l
#     16                    name:whole
#     16                    name:total
#     16                    name:first
#     16  name:δ9-tetrahydrocannabinol
#     16                  name:chronic
#     16                    name:ng/ml
#     16                  name:reports
#     16                  name:opiates
#     16                 name:presents
#     16               name:individual
#     16                     name:oral
#     16             name:inflammatory
#     16                 name:olivetol
#     16                    name:phase
#     16                name:specimens
#     15               name:structural
#     15                name:synthetic
# ----------------------------------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=diseases
#  Count                   Query
#     42           name:analytes
# ...
#    87087                                                                                           flna_human
#    66485                                                                  reviewed:yes organism:9606 gene:nan
#    50757                                                                                           fibb_human
#    48660                                                        accession:a1ag1_human or mnemonic:a1ag1_human
#    44170                                                                                           finc_human
#    42524                                                                                          ighg1_human
#    40458                                                                                           fibg_human
#    32150                                                                                           tagl_human
#    31197                                                                                           vime_human
#    28616                                                                  accession:p01174 or mnemonic:p01174
#    25592                                                                       organism:9606 and reviewed:yes
#    23679                                                        accession:a1ag1_mouse or mnemonic:a1ag1_mouse
#    23679                                                                                          ctge5_human
#    23598                                                                                           ighm_human
#    23131                                                                       reviewed:yes and organism:9606
#    23124                                                                                           fiba_human
#    22933                                                                                            hbb_human
#    22697                                                                                           ahnk_human
#    22106                                                            accession:wap_mouse or mnemonic:wap_mouse
#    21677                                                           organism:homo sapiens and gene_exact: rp11
#    21228                                                                                           apob_human
#    21041                                                                                     accession:p04264
#    20912                                                                                     accession:p35908
#    20822                                                                            q8wz42 and organism:human
#    20675                                                                                     accession:p13645
#    20617                                                                                     accession:p35527
#    17320                                                                                          actn1_human
#    17066  accession:wap_rat or mnemonic:wap_rat or accession:wap_mouse or mnemonic:wap_mouse or accession:...
#    16957                                                                                           a1at_human
#    16944                                                                                           vinc_human
#    16439                                                                                          igha1_human
#    15473                                                                                            co3_human
#    15008                                                                                            hba_human
#    14807                                                                                           a2mg_human
#    13253                                                                                          actn4_human
#    13043                                                                                           erg5_yeast
#    12464                                                                                            hpt_human
#    12269                                                                     organism:cyanidioschyzon merolae
#    12085                                                            accession:undefined or mnemonic:undefined
#    12072                                                                                     accession:p02769
#    12057                                                                                           acta_human
#    11720                                                                                           tpm1_human
#    11303                                                                                      ensp00000000233
#    10558                                                                               organism:9606 gene:nan
#    10318                                                                                           kpym_human
#     9910                                                                                     accession:p04637
#     9695                                                                                          apoa1_human
#     9691                                                                                           trfe_human
#     9675                                                          accession:ynb3_yeast or mnemonic:ynb3_yeast
#     9539                                                                                          ighg2_human
#     9210                                                                                           tpm2_human
#     9055                                                                                           enoa_human
#     9043                                                                  accession:p43780 or mnemonic:p43780
#     8793  accession:af221634.1ak291057.1ak000290.1bc030688.2q6v1x1-2q6v1x1-3q6v1x1-4q6v1x1-5q6v1x1-6q6v1x1...
#     8775                                                                                     accession:p11369
#     8695                                                                                            g3p_human
#     8269                                                                                            h31_human
#     8115                                                                                           clus_human
#     7915                                                                                           actb_human
#     7891                                                                                          igll5_human
#     7741                                                                                           tln1_human
#     7693                                                                                           lac2_human
#     7436                                                                                             h4_human
#     7141                                                                                taxonomy:77133 and s7
#     6951                                                                  accession:xxx111 or mnemonic:xxx111
#     6941                                                                                               xxx111
#     6926                                                                                  reachr reviewed:yes
#     6832                                                           gene:col4a2-as2 organism:9606 reviewed:yes
#     6831                                                              nm_001267044 organism:9606 reviewed:yes
#     6747                                                                                           pgbm_human
#     6657                                                                                          cald1_human
#     6645                                                                    ec:1.3.1.93 and taxonomy:bacteria
#     6635                                                                                              id:none
#     6619                                                   ec:1.3.1.93 and reviewed:yes and taxonomy:bacteria
#     6598                                                                                               reachr
#     6596                                                  ec:4.2.1.134 and reviewed:yes and taxonomy:bacteria
#     6573                                                                                          itih1_human
#     6558                                                                   ec:4.2.1.134 and taxonomy:bacteria
#     6447                                                                                          anxa2_human
#     6234                                                                                           cfah_human
#     6192                                                                  accession:p02768 or mnemonic:p02768
#     6049                                                                                          tagl2_human
#     6036                                                          accession:roa1_human or mnemonic:roa1_human
#     5954                                                                  accession:a2ass6 or mnemonic:a2ass6
#     5883                                                                                           gels_human
# ----------------------------------------------------------------------------------------------------
#
#
# User type=programmatic Namespace=proteomes
#  Count                                                   Query
#   1375                                                       *
#    595                                              salmonella
#    592                                           lactobacillus
#    592                                           streptococcus
#    590                                                   human
#    589                                                     cat
#    588                                                   mouse
#    105                                           reference:yes
#     95                                            homo_sapiens
#     90                                                    asfv
#     71                                   neisseria gonorrhoeae
#     49  mycobacterium tuberculosis (strain atcc 25618 / h37rv)
#     42                                           name:analytes
#     40                              streptococcus thermophilus
#     39                                           name:cannabis
#     37                                             name:values
#     36                                          name:indicates
#     36                                            name:samples
#     35                                           name:extracts
#     35                                             name:ranges
#     34                                             name:limits
#     33                                reference:yes taxonomy:2
#     32                                        name:metabolites
#     31                                            mus_musculus
#     30                                taxonomy:24 redundant:no
#     29                                        name:cannabinoid
#     29                                            redundant:no
#     29                                           taxonomy:4577
#     29                                          name:compounds
#     26                                           name:suggests
#     26                                              name:means
#     26                                               name:acid
#     25                                         name:bioaerosol
#     25                                        name:cannabidiol
#     25                                             name:sativa
#     25                                              name:study
#     25                                               name:mean
#     24                                             name:method
#     24                                          name:marijuana
#     23                                           name:requires
#     23                                            name:methods
#     22                                           name:agonists
#     22                                      bacillus anthracis
#     22                                                name:thc
#     22                                              name:delta
#     22                                                name:rat
#     22                                              name:novel
#     22                                              name:doses
#     21                                               name:high
#     21                                            name:results
#     20                                              name:urine
#     20                                                name:due
#     20                                            name:overall
#     20                                         name:extraction
#     20                                           name:presents
#     20                                              name:vitro
#     20                                             name:direct
#     20                                          name:determine
#     19                                            name:opiates
#     19                                               name:aims
#     19                                             name:plasma
#     19                                          name:specimens
#     19                                            name:windows
#     19                             reference:yes taxonomy:7227
#     19                                               name:hair
#     19                                                name:key
#     19                                             name:liquid
#     18                                            name:purpose
#     18                                              name:acute
#     18                                          name:knowledge
#     18                                         name:background
#     18                                           name:decrease
#     18                                           name:identify
#     18                             reference:yes taxonomy:4751
#     18                                         name:identified
#     18                                  pseudomonas aeruginosa
#     17                                                name:use
#     17                                             name:become
#     17                                             name:curves
#     17                             reference:yes taxonomy:9913
#     17                                             name:sample
#     17                                               name:bias
#     17                                               name:hemp
#     17                                              name:avoid
#     17                                       name:experimental
#     17                                                name:low
#     17                                           name:evaluate
#     17                                               name:test
#     17                                               name:μg/l
#     17                                              name:human
#     17                                              name:whole
#     16                            name:δ9-tetrahydrocannabinol
#     16                                         name:individual
#     16                                                    homo
#     16                                           name:absolute
#     16                                         name:functional
#     16                                            name:cocaine
#     16                                           name:compound
#     16                                            name:medical
#     16                                       name:cannabinoids
# ----------------------------------------------------------------------------------------------------
